# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip uninstall qiskit qiskit-aer  qiskit-braket-provider  qiskit-ibm-runtime  qiskit-ionq qiskit-terra -y
# Out:
# WARNING: Skipping qiskit as it is not installed.
# WARNING: Skipping qiskit-aer as it is not installed.
# WARNING: Skipping qiskit-braket-provider as it is not installed.
# WARNING: Skipping qiskit-ibm-runtime as it is not installed.
# WARNING: Skipping qiskit-ionq as it is not installed.
# Found existing installation: qiskit-terra 0.46.2
# Uninstalling qiskit-terra-0.46.2:
#   Successfully uninstalled qiskit-terra-0.46.2

# %%
# !pip list
# Out:
# Package                           Version
# --------------------------------- ---------------------
# absl-py                           1.4.0
# accelerate                        0.32.1
# aiohttp                           3.9.5
# aiosignal                         1.3.1
# alabaster                         0.7.16
# albucore                          0.0.12
# albumentations                    1.4.12
# altair                            4.2.2
# amazon-braket-default-simulator   1.26.0
# amazon-braket-schemas             1.22.0
# amazon-braket-sdk                 1.84.0
# annotated-types                   0.7.0
# antlr4-python3-runtime            4.9.2
# anyio                             3.7.1
# argon2-cffi                       23.1.0
# argon2-cffi-bindings              21.2.0
# array_record                      0.5.1
# arviz                             0.18.0
# asn1crypto                        1.5.1
# astropy                           6.1.2
# astropy-iers-data                 0.2024.7.29.0.32.7
# astunparse                        1.6.3
# async-timeout                     4.0.3
# atpublic                          4.1.0
# attrs                             23.2.0
# audioread                         3.0.1
# autograd                          1.6.2
# Babel                             2.15.0
# backcall                          0.2.0
# backoff                           2.2.1
# backports.entry-points-selectable 1.3.0
# beautifulsoup4                    4.12.3
# bidict                            0.23.1
# bigframes                         1.11.1
# bleach                            6.1.0
# blinker                           1.4
# blis                              0.7.11
# blosc2                            2.0.0
# bokeh                             3.4.3
# boltons                           24.0.0
# boto3                             1.34.151
# botocore                          1.34.151
# bqplot                            0.12.43
# branca                            0.7.2
# build                             1.2.1
# CacheControl                      0.14.0
# cachetools                        5.4.0
# catalogue                         2.0.10
# certifi                           2024.7.4
# cffi                              1.16.0
# chardet                           5.2.0
# charset-normalizer                3.3.2
# chex                              0.1.86
# clarabel                          0.9.0
# click                             8.1.7
# click-plugins                     1.1.1
# cligj                             0.7.2
# cloudpathlib                      0.18.1
# cloudpickle                       2.2.1
# cmake                             3.30.1
# cmdstanpy                         1.2.4
# colorcet                          3.1.0
# colorlover                        0.3.0
# colour                            0.1.5
# community                         1.0.0b1
# confection                        0.1.5
# cons                              0.4.6
# contextlib2                       21.6.0
# contourpy                         1.2.1
# cryptography                      42.0.8
# cuda-python                       12.2.1
# cudf-cu12                         24.4.1
# cufflinks                         0.17.3
# cupy-cuda12x                      12.2.0
# cvxopt                            1.3.2
# cvxpy                             1.5.2
# cycler                            0.12.1
# cymem                             2.0.8
# Cython                            3.0.10
# dask                              2024.7.1
# datascience                       0.17.6
# db-dtypes                         1.2.0
# dbus-python                       1.2.18
# debugpy                           1.6.6
# decorator                         5.1.1
# defusedxml                        0.7.1
# dill                              0.3.8
# distributed                       2024.7.1
# distro                            1.7.0
# dlib                              19.24.2
# dm-tree                           0.1.8
# docstring_parser                  0.16
# docutils                          0.18.1
# dopamine_rl                       4.0.9
# duckdb                            0.10.3
# earthengine-api                   0.1.414
# easydict                          1.13
# ecos                              2.0.14
# editdistance                      0.8.1
# eerepr                            0.0.4
# en-core-web-sm                    3.7.1
# entrypoints                       0.4
# et-xmlfile                        1.1.0
# etils                             1.7.0
# etuples                           0.3.9
# eval_type_backport                0.2.0
# exceptiongroup                    1.2.2
# fastai                            2.7.15
# fastcore                          1.5.55
# fastdownload                      0.0.7
# fastjsonschema                    2.20.0
# fastprogress                      1.0.3
# fastrlock                         0.8.2
# filelock                          3.15.4
# fiona                             1.9.6
# firebase-admin                    6.5.0
# Flask                             2.2.5
# flatbuffers                       24.3.25
# flax                              0.8.4
# folium                            0.17.0
# fonttools                         4.53.1
# frozendict                        2.4.4
# frozenlist                        1.4.1
# fsspec                            2024.6.1
# future                            1.0.0
# gast                              0.6.0
# gcsfs                             2024.6.1
# GDAL                              3.6.4
# gdown                             5.1.0
# geemap                            0.33.1
# gensim                            4.3.3
# geocoder                          1.38.1
# geographiclib                     2.0
# geopandas                         0.14.4
# geopy                             2.4.1
# gin-config                        0.5.0
# glob2                             0.7
# google                            2.0.3
# google-ai-generativelanguage      0.6.6
# google-api-core                   2.19.1
# google-api-python-client          2.137.0
# google-auth                       2.27.0
# google-auth-httplib2              0.2.0
# google-auth-oauthlib              1.2.1
# google-cloud-aiplatform           1.59.0
# google-cloud-bigquery             3.25.0
# google-cloud-bigquery-connection  1.15.4
# google-cloud-bigquery-storage     2.25.0
# google-cloud-bigtable             2.25.0
# google-cloud-core                 2.4.1
# google-cloud-datastore            2.19.0
# google-cloud-firestore            2.16.1
# google-cloud-functions            1.16.4
# google-cloud-iam                  2.15.1
# google-cloud-language             2.13.4
# google-cloud-pubsub               2.23.0
# google-cloud-resource-manager     1.12.4
# google-cloud-storage              2.8.0
# google-cloud-translate            3.15.4
# google-colab                      1.0.0
# google-crc32c                     1.5.0
# google-generativeai               0.7.2
# google-pasta                      0.2.0
# google-resumable-media            2.7.1
# googleapis-common-protos          1.63.2
# googledrivedownloader             0.4
# graphviz                          0.20.3
# greenlet                          3.0.3
# grpc-google-iam-v1                0.13.1
# grpcio                            1.64.1
# grpcio-status                     1.48.2
# gspread                           6.0.2
# gspread-dataframe                 3.3.1
# gym                               0.25.2
# gym-notices                       0.0.8
# h5netcdf                          1.3.0
# h5py                              3.11.0
# holidays                          0.53
# holoviews                         1.18.3
# html5lib                          1.1
# httpimport                        1.3.1
# httplib2                          0.22.0
# huggingface-hub                   0.23.5
# humanize                          4.10.0
# hyperopt                          0.2.7
# ibis-framework                    8.0.0
# ibm-cloud-sdk-core                3.20.4
# ibm-platform-services             0.55.2
# idna                              3.7
# imageio                           2.34.2
# imageio-ffmpeg                    0.5.1
# imagesize                         1.4.1
# imbalanced-learn                  0.12.3
# imgaug                            0.4.0
# immutabledict                     4.2.0
# importlib_metadata                8.2.0
# importlib_resources               6.4.0
# imutils                           0.5.4
# inflect                           7.3.1
# iniconfig                         2.0.0
# intel-cmplr-lib-ur                2024.2.0
# intel-openmp                      2024.2.0
# ipyevents                         2.0.2
# ipyfilechooser                    0.6.0
# ipykernel                         5.5.6
# ipyleaflet                        0.18.2
# ipyparallel                       8.8.0
# ipython                           7.34.0
# ipython-genutils                  0.2.0
# ipython-sql                       0.5.0
# ipytree                           0.2.2
# ipywidgets                        7.7.1
# itsdangerous                      2.2.0
# jax                               0.4.26
# jaxlib                            0.4.26+cuda12.cudnn89
# jedi                              0.19.1
# jeepney                           0.7.1
# jellyfish                         1.1.0
# jieba                             0.42.1
# Jinja2                            3.1.4
# jmespath                          1.0.1
# joblib                            1.4.2
# jsonpickle                        3.2.2
# jsonschema                        4.23.0
# jsonschema-specifications         2023.12.1
# jupyter-client                    6.1.12
# jupyter-console                   6.1.0
# jupyter_core                      5.7.2
# jupyter-server                    1.24.0
# jupyterlab_pygments               0.3.0
# jupyterlab_widgets                3.0.11
# kaggle                            1.6.17
# kagglehub                         0.2.8
# keras                             3.4.1
# keyring                           23.5.0
# kiwisolver                        1.4.5
# langcodes                         3.4.0
# language_data                     1.2.0
# launchpadlib                      1.10.16
# lazr.restfulclient                0.14.4
# lazr.uri                          1.0.6
# lazy_loader                       0.4
# libclang                          18.1.1
# librosa                           0.10.2.post1
# lightgbm                          4.4.0
# linkify-it-py                     2.0.3
# llvmlite                          0.43.0
# locket                            1.0.0
# logical-unification               0.4.6
# lxml                              4.9.4
# malloy                            2024.1089
# marisa-trie                       1.2.0
# Markdown                          3.6
# markdown-it-py                    3.0.0
# MarkupSafe                        2.1.5
# matplotlib                        3.7.1
# matplotlib-inline                 0.1.7
# matplotlib-venn                   0.11.10
# mdit-py-plugins                   0.4.1
# mdurl                             0.1.2
# miniKanren                        1.0.3
# missingno                         0.5.2
# mistune                           0.8.4
# mizani                            0.9.3
# mkl                               2024.2.0
# ml-dtypes                         0.4.0
# mlxtend                           0.23.1
# more-itertools                    10.3.0
# moviepy                           1.0.3
# mpmath                            1.3.0
# msgpack                           1.0.8
# multidict                         6.0.5
# multipledispatch                  1.0.0
# multitasking                      0.0.11
# murmurhash                        1.0.10
# music21                           9.1.0
# mypy-extensions                   1.0.0
# namex                             0.0.8
# natsort                           8.4.0
# nbclassic                         1.1.0
# nbclient                          0.10.0
# nbconvert                         6.5.4
# nbformat                          5.10.4
# nest-asyncio                      1.6.0
# networkx                          3.3
# nibabel                           5.0.1
# nltk                              3.8.1
# notebook                          6.5.5
# notebook_shim                     0.2.4
# numba                             0.60.0
# numexpr                           2.10.1
# numpy                             1.26.4
# nvtx                              0.2.10
# oauth2client                      4.1.3
# oauthlib                          3.2.2
# opencv-contrib-python             4.10.0.84
# opencv-python                     4.10.0.84
# opencv-python-headless            4.10.0.84
# openpulse                         0.5.0
# openpyxl                          3.1.5
# openqasm3                         1.0.0
# opt-einsum                        3.3.0
# optax                             0.2.2
# optree                            0.12.1
# oqpy                              0.3.6
# orbax-checkpoint                  0.5.23
# osqp                              0.6.7.post0
# packaging                         24.1
# pandas                            2.1.4
# pandas-datareader                 0.10.0
# pandas-gbq                        0.19.2
# pandas-stubs                      2.1.4.231227
# pandocfilters                     1.5.1
# panel                             1.4.4
# param                             2.1.1
# parso                             0.8.4
# parsy                             2.1
# partd                             1.4.2
# pathlib                           1.0.1
# patsy                             0.5.6
# pbr                               6.0.0
# peewee                            3.17.6
# pexpect                           4.9.0
# pickleshare                       0.7.5
# Pillow                            9.4.0
# pip                               24.1.2
# pip-tools                         7.4.1
# platformdirs                      4.2.2
# plotly                            5.15.0
# plotnine                          0.12.4
# pluggy                            1.5.0
# ply                               3.11
# polars                            0.20.2
# pooch                             1.8.2
# portpicker                        1.5.2
# prefetch_generator                1.0.3
# preshed                           3.0.9
# prettytable                       3.10.2
# proglog                           0.1.10
# progressbar2                      4.2.0
# prometheus_client                 0.20.0
# promise                           2.3
# prompt_toolkit                    3.0.47
# prophet                           1.1.5
# proto-plus                        1.24.0
# protobuf                          3.20.3
# psutil                            5.9.5
# psycopg2                          2.9.9
# ptyprocess                        0.7.0
# py                                1.11.0
# py-cpuinfo                        9.0.0
# py4j                              0.10.9.7
# pyarrow                           14.0.2
# pyarrow-hotfix                    0.6
# pyasn1                            0.6.0
# pyasn1_modules                    0.4.0
# pycocotools                       2.0.8
# pycparser                         2.22
# pydantic                          2.8.2
# pydantic_core                     2.20.1
# pydata-google-auth                1.8.2
# pydot                             1.4.2
# pydot-ng                          2.0.0
# pydotplus                         2.0.2
# PyDrive                           1.3.1
# PyDrive2                          1.6.3
# pyerfa                            2.0.1.4
# pygame                            2.6.0
# Pygments                          2.16.1
# PyGObject                         3.42.1
# PyJWT                             2.8.0
# pylatexenc                        2.10
# pymc                              5.10.4
# pymystem3                         0.2.0
# pynvjitlink-cu12                  0.3.0
# PyOpenGL                          3.1.7
# pyOpenSSL                         24.2.1
# pyparsing                         3.1.2
# pyperclip                         1.9.0
# pyproj                            3.6.1
# pyproject_hooks                   1.1.0
# pyshp                             2.3.1
# PySocks                           1.7.1
# pyspnego                          0.11.1
# pytensor                          2.18.6
# pytest                            7.4.4
# python-apt                        2.4.0
# python-box                        7.2.0
# python-dateutil                   2.8.2
# python-louvain                    0.16
# python-slugify                    8.0.4
# python-utils                      3.8.2
# pytz                              2024.1
# pyviz_comms                       3.0.2
# PyYAML                            6.0.1
# pyzmq                             24.0.1
# qdldl                             0.1.7.post4
# ratelim                           0.1.6
# referencing                       0.35.1
# regex                             2024.5.15
# requests                          2.31.0
# requests_ntlm                     1.3.0
# requests-oauthlib                 1.3.1
# requirements-parser               0.9.0
# retry                             0.9.2
# rich                              13.7.1
# rmm-cu12                          24.4.0
# rpds-py                           0.19.1
# rpy2                              3.4.2
# rsa                               4.9
# rustworkx                         0.15.1
# s3transfer                        0.10.2
# safetensors                       0.4.3
# scikit-image                      0.23.2
# scikit-learn                      1.3.2
# scipy                             1.13.1
# scooby                            0.10.0
# scs                               3.2.6
# seaborn                           0.13.1
# SecretStorage                     3.3.1
# Send2Trash                        1.8.3
# sentencepiece                     0.1.99
# setuptools                        69.5.1
# shapely                           2.0.5
# shellingham                       1.5.4
# simple_parsing                    0.1.5
# six                               1.16.0
# sklearn-pandas                    2.2.0
# smart-open                        7.0.4
# sniffio                           1.3.1
# snowballstemmer                   2.2.0
# snowflake-connector-python        3.12.0
# sortedcontainers                  2.4.0
# soundfile                         0.12.1
# soupsieve                         2.5
# soxr                              0.4.0
# spacy                             3.7.5
# spacy-legacy                      3.0.12
# spacy-loggers                     1.0.5
# Sphinx                            5.0.2
# sphinxcontrib-applehelp           2.0.0
# sphinxcontrib-devhelp             2.0.0
# sphinxcontrib-htmlhelp            2.1.0
# sphinxcontrib-jsmath              1.0.1
# sphinxcontrib-qthelp              2.0.0
# sphinxcontrib-serializinghtml     2.0.0
# SQLAlchemy                        2.0.31
# sqlglot                           20.11.0
# sqlparse                          0.5.1
# srsly                             2.4.8
# stanio                            0.5.1
# statsmodels                       0.14.2
# stevedore                         5.2.0
# StrEnum                           0.4.15
# symengine                         0.11.0
# sympy                             1.13.1
# tables                            3.8.0
# tabulate                          0.9.0
# tbb                               2021.13.0
# tblib                             3.0.0
# tenacity                          9.0.0
# tensorboard                       2.17.0
# tensorboard-data-server           0.7.2
# tensorflow                        2.17.0
# tensorflow-datasets               4.9.6
# tensorflow-hub                    0.16.1
# tensorflow-io-gcs-filesystem      0.37.1
# tensorflow-metadata               1.15.0
# tensorflow-probability            0.24.0
# tensorstore                       0.1.63
# termcolor                         2.4.0
# terminado                         0.18.1
# text-unidecode                    1.3
# textblob                          0.17.1
# tf_keras                          2.17.0
# tf-slim                           1.1.0
# thinc                             8.2.5
# threadpoolctl                     3.5.0
# tifffile                          2024.7.24
# tinycss2                          1.3.0
# tokenizers                        0.19.1
# toml                              0.10.2
# tomli                             2.0.1
# tomlkit                           0.13.0
# toolz                             0.12.1
# torch                             2.3.1+cu121
# torchaudio                        2.3.1+cu121
# torchsummary                      1.5.1
# torchtext                         0.18.0
# torchvision                       0.18.1+cu121
# tornado                           6.3.3
# tqdm                              4.66.4
# traitlets                         5.7.1
# traittypes                        0.2.1
# transformers                      4.42.4
# triton                            2.3.1
# tweepy                            4.14.0
# typeguard                         4.3.0
# typer                             0.12.3
# types-pytz                        2024.1.0.20240417
# types-setuptools                  71.1.0.20240726
# typing_extensions                 4.12.2
# tzdata                            2024.1
# tzlocal                           5.2
# uc-micro-py                       1.0.3
# uritemplate                       4.1.1
# urllib3                           2.2.2
# vega-datasets                     0.9.0
# wadllib                           1.3.6
# wasabi                            1.1.3
# wcwidth                           0.2.13
# weasel                            0.4.1
# webcolors                         24.6.0
# webencodings                      0.5.1
# websocket-client                  1.8.0
# Werkzeug                          3.0.3
# wheel                             0.43.0
# widgetsnbextension                3.6.8
# wordcloud                         1.9.3
# wrapt                             1.16.0
# xarray                            2024.6.0
# xarray-einstats                   0.7.0
# xgboost                           2.1.0
# xlrd                              2.0.1
# xyzservices                       2024.6.0
# yarl                              1.9.4
# yellowbrick                       1.5
# yfinance                          0.2.41
# zict                              3.0.0
# zipp                              3.19.2

# %%
# !pip install qiskit==1.1.1  --no-cache-dir
# Out:
# Collecting qiskit==1.1.1
#   Downloading qiskit-1.1.1-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: rustworkx>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from qiskit==1.1.1) (0.15.1)
# Requirement already satisfied: numpy<3,>=1.17 in /usr/local/lib/python3.10/dist-packages (from qiskit==1.1.1) (1.26.4)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.10/dist-packages (from qiskit==1.1.1) (1.13.1)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.10/dist-packages (from qiskit==1.1.1) (1.13.1)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.10/dist-packages (from qiskit==1.1.1) (0.3.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from qiskit==1.1.1) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from qiskit==1.1.1) (5.2.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from qiskit==1.1.1) (4.12.2)
# Requirement already satisfied: symengine>=0.11 in /usr/local/lib/python3.10/dist-packages (from qiskit==1.1.1) (0.11.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.0->qiskit==1.1.1) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from stevedore>=3.0.0->qiskit==1.1.1) (6.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.3->qiskit==1.1.1) (1.3.0)
# Downloading qiskit-1.1.1-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 39.7 MB/s eta 0:00:00
# Installing collected packages: qiskit
# Successfully installed qiskit-1.1.1

# %%
####!pip install openai
# !pip install numpy
# !pip install pandas
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !pip list
# Out:
# Package                           Version
# --------------------------------- ---------------------
# absl-py                           1.4.0
# accelerate                        0.32.1
# aiohttp                           3.9.5
# aiosignal                         1.3.1
# alabaster                         0.7.16
# albucore                          0.0.12
# albumentations                    1.4.12
# altair                            4.2.2
# amazon-braket-default-simulator   1.26.0
# amazon-braket-schemas             1.22.0
# amazon-braket-sdk                 1.84.0
# annotated-types                   0.7.0
# antlr4-python3-runtime            4.9.2
# anyio                             3.7.1
# argon2-cffi                       23.1.0
# argon2-cffi-bindings              21.2.0
# array_record                      0.5.1
# arviz                             0.18.0
# asn1crypto                        1.5.1
# astropy                           6.1.2
# astropy-iers-data                 0.2024.7.29.0.32.7
# astunparse                        1.6.3
# async-timeout                     4.0.3
# atpublic                          4.1.0
# attrs                             23.2.0
# audioread                         3.0.1
# autograd                          1.6.2
# Babel                             2.15.0
# backcall                          0.2.0
# backoff                           2.2.1
# backports.entry-points-selectable 1.3.0
# beautifulsoup4                    4.12.3
# bidict                            0.23.1
# bigframes                         1.11.1
# bleach                            6.1.0
# blinker                           1.4
# blis                              0.7.11
# blosc2                            2.0.0
# bokeh                             3.4.3
# boltons                           24.0.0
# boto3                             1.34.151
# botocore                          1.34.151
# bqplot                            0.12.43
# branca                            0.7.2
# build                             1.2.1
# CacheControl                      0.14.0
# cachetools                        5.4.0
# catalogue                         2.0.10
# certifi                           2024.7.4
# cffi                              1.16.0
# chardet                           5.2.0
# charset-normalizer                3.3.2
# chex                              0.1.86
# clarabel                          0.9.0
# click                             8.1.7
# click-plugins                     1.1.1
# cligj                             0.7.2
# cloudpathlib                      0.18.1
# cloudpickle                       2.2.1
# cmake                             3.30.1
# cmdstanpy                         1.2.4
# colorcet                          3.1.0
# colorlover                        0.3.0
# colour                            0.1.5
# community                         1.0.0b1
# confection                        0.1.5
# cons                              0.4.6
# contextlib2                       21.6.0
# contourpy                         1.2.1
# cryptography                      42.0.8
# cuda-python                       12.2.1
# cudf-cu12                         24.4.1
# cufflinks                         0.17.3
# cupy-cuda12x                      12.2.0
# cvxopt                            1.3.2
# cvxpy                             1.5.2
# cycler                            0.12.1
# cymem                             2.0.8
# Cython                            3.0.10
# dask                              2024.7.1
# datascience                       0.17.6
# db-dtypes                         1.2.0
# dbus-python                       1.2.18
# debugpy                           1.6.6
# decorator                         5.1.1
# defusedxml                        0.7.1
# dill                              0.3.8
# distributed                       2024.7.1
# distro                            1.7.0
# dlib                              19.24.2
# dm-tree                           0.1.8
# docstring_parser                  0.16
# docutils                          0.18.1
# dopamine_rl                       4.0.9
# duckdb                            0.10.3
# earthengine-api                   0.1.414
# easydict                          1.13
# ecos                              2.0.14
# editdistance                      0.8.1
# eerepr                            0.0.4
# en-core-web-sm                    3.7.1
# entrypoints                       0.4
# et-xmlfile                        1.1.0
# etils                             1.7.0
# etuples                           0.3.9
# eval_type_backport                0.2.0
# exceptiongroup                    1.2.2
# fastai                            2.7.15
# fastcore                          1.5.55
# fastdownload                      0.0.7
# fastjsonschema                    2.20.0
# fastprogress                      1.0.3
# fastrlock                         0.8.2
# filelock                          3.15.4
# fiona                             1.9.6
# firebase-admin                    6.5.0
# Flask                             2.2.5
# flatbuffers                       24.3.25
# flax                              0.8.4
# folium                            0.17.0
# fonttools                         4.53.1
# frozendict                        2.4.4
# frozenlist                        1.4.1
# fsspec                            2024.6.1
# future                            1.0.0
# gast                              0.6.0
# gcsfs                             2024.6.1
# GDAL                              3.6.4
# gdown                             5.1.0
# geemap                            0.33.1
# gensim                            4.3.3
# geocoder                          1.38.1
# geographiclib                     2.0
# geopandas                         0.14.4
# geopy                             2.4.1
# gin-config                        0.5.0
# glob2                             0.7
# google                            2.0.3
# google-ai-generativelanguage      0.6.6
# google-api-core                   2.19.1
# google-api-python-client          2.137.0
# google-auth                       2.27.0
# google-auth-httplib2              0.2.0
# google-auth-oauthlib              1.2.1
# google-cloud-aiplatform           1.59.0
# google-cloud-bigquery             3.25.0
# google-cloud-bigquery-connection  1.15.4
# google-cloud-bigquery-storage     2.25.0
# google-cloud-bigtable             2.25.0
# google-cloud-core                 2.4.1
# google-cloud-datastore            2.19.0
# google-cloud-firestore            2.16.1
# google-cloud-functions            1.16.4
# google-cloud-iam                  2.15.1
# google-cloud-language             2.13.4
# google-cloud-pubsub               2.23.0
# google-cloud-resource-manager     1.12.4
# google-cloud-storage              2.8.0
# google-cloud-translate            3.15.4
# google-colab                      1.0.0
# google-crc32c                     1.5.0
# google-generativeai               0.7.2
# google-pasta                      0.2.0
# google-resumable-media            2.7.1
# googleapis-common-protos          1.63.2
# googledrivedownloader             0.4
# graphviz                          0.20.3
# greenlet                          3.0.3
# grpc-google-iam-v1                0.13.1
# grpcio                            1.64.1
# grpcio-status                     1.48.2
# gspread                           6.0.2
# gspread-dataframe                 3.3.1
# gym                               0.25.2
# gym-notices                       0.0.8
# h5netcdf                          1.3.0
# h5py                              3.11.0
# holidays                          0.53
# holoviews                         1.18.3
# html5lib                          1.1
# httpimport                        1.3.1
# httplib2                          0.22.0
# huggingface-hub                   0.23.5
# humanize                          4.10.0
# hyperopt                          0.2.7
# ibis-framework                    8.0.0
# ibm-cloud-sdk-core                3.20.4
# ibm-platform-services             0.55.2
# idna                              3.7
# imageio                           2.34.2
# imageio-ffmpeg                    0.5.1
# imagesize                         1.4.1
# imbalanced-learn                  0.12.3
# imgaug                            0.4.0
# immutabledict                     4.2.0
# importlib_metadata                8.2.0
# importlib_resources               6.4.0
# imutils                           0.5.4
# inflect                           7.3.1
# iniconfig                         2.0.0
# intel-cmplr-lib-ur                2024.2.0
# intel-openmp                      2024.2.0
# ipyevents                         2.0.2
# ipyfilechooser                    0.6.0
# ipykernel                         5.5.6
# ipyleaflet                        0.18.2
# ipyparallel                       8.8.0
# ipython                           7.34.0
# ipython-genutils                  0.2.0
# ipython-sql                       0.5.0
# ipytree                           0.2.2
# ipywidgets                        7.7.1
# itsdangerous                      2.2.0
# jax                               0.4.26
# jaxlib                            0.4.26+cuda12.cudnn89
# jedi                              0.19.1
# jeepney                           0.7.1
# jellyfish                         1.1.0
# jieba                             0.42.1
# Jinja2                            3.1.4
# jmespath                          1.0.1
# joblib                            1.4.2
# jsonpickle                        3.2.2
# jsonschema                        4.23.0
# jsonschema-specifications         2023.12.1
# jupyter-client                    6.1.12
# jupyter-console                   6.1.0
# jupyter_core                      5.7.2
# jupyter-server                    1.24.0
# jupyterlab_pygments               0.3.0
# jupyterlab_widgets                3.0.11
# kaggle                            1.6.17
# kagglehub                         0.2.8
# keras                             3.4.1
# keyring                           23.5.0
# kiwisolver                        1.4.5
# langcodes                         3.4.0
# language_data                     1.2.0
# launchpadlib                      1.10.16
# lazr.restfulclient                0.14.4
# lazr.uri                          1.0.6
# lazy_loader                       0.4
# libclang                          18.1.1
# librosa                           0.10.2.post1
# lightgbm                          4.4.0
# linkify-it-py                     2.0.3
# llvmlite                          0.43.0
# locket                            1.0.0
# logical-unification               0.4.6
# lxml                              4.9.4
# malloy                            2024.1089
# marisa-trie                       1.2.0
# Markdown                          3.6
# markdown-it-py                    3.0.0
# MarkupSafe                        2.1.5
# matplotlib                        3.7.1
# matplotlib-inline                 0.1.7
# matplotlib-venn                   0.11.10
# mdit-py-plugins                   0.4.1
# mdurl                             0.1.2
# miniKanren                        1.0.3
# missingno                         0.5.2
# mistune                           0.8.4
# mizani                            0.9.3
# mkl                               2024.2.0
# ml-dtypes                         0.4.0
# mlxtend                           0.23.1
# more-itertools                    10.3.0
# moviepy                           1.0.3
# mpmath                            1.3.0
# msgpack                           1.0.8
# multidict                         6.0.5
# multipledispatch                  1.0.0
# multitasking                      0.0.11
# murmurhash                        1.0.10
# music21                           9.1.0
# mypy-extensions                   1.0.0
# namex                             0.0.8
# natsort                           8.4.0
# nbclassic                         1.1.0
# nbclient                          0.10.0
# nbconvert                         6.5.4
# nbformat                          5.10.4
# nest-asyncio                      1.6.0
# networkx                          3.3
# nibabel                           5.0.1
# nltk                              3.8.1
# notebook                          6.5.5
# notebook_shim                     0.2.4
# numba                             0.60.0
# numexpr                           2.10.1
# numpy                             1.26.4
# nvtx                              0.2.10
# oauth2client                      4.1.3
# oauthlib                          3.2.2
# opencv-contrib-python             4.10.0.84
# opencv-python                     4.10.0.84
# opencv-python-headless            4.10.0.84
# openpulse                         0.5.0
# openpyxl                          3.1.5
# openqasm3                         1.0.0
# opt-einsum                        3.3.0
# optax                             0.2.2
# optree                            0.12.1
# oqpy                              0.3.6
# orbax-checkpoint                  0.5.23
# osqp                              0.6.7.post0
# packaging                         24.1
# pandas                            2.1.4
# pandas-datareader                 0.10.0
# pandas-gbq                        0.19.2
# pandas-stubs                      2.1.4.231227
# pandocfilters                     1.5.1
# panel                             1.4.4
# param                             2.1.1
# parso                             0.8.4
# parsy                             2.1
# partd                             1.4.2
# pathlib                           1.0.1
# patsy                             0.5.6
# pbr                               6.0.0
# peewee                            3.17.6
# pexpect                           4.9.0
# pickleshare                       0.7.5
# Pillow                            9.4.0
# pip                               24.1.2
# pip-tools                         7.4.1
# platformdirs                      4.2.2
# plotly                            5.15.0
# plotnine                          0.12.4
# pluggy                            1.5.0
# ply                               3.11
# polars                            0.20.2
# pooch                             1.8.2
# portpicker                        1.5.2
# prefetch_generator                1.0.3
# preshed                           3.0.9
# prettytable                       3.10.2
# proglog                           0.1.10
# progressbar2                      4.2.0
# prometheus_client                 0.20.0
# promise                           2.3
# prompt_toolkit                    3.0.47
# prophet                           1.1.5
# proto-plus                        1.24.0
# protobuf                          3.20.3
# psutil                            5.9.5
# psycopg2                          2.9.9
# ptyprocess                        0.7.0
# py                                1.11.0
# py-cpuinfo                        9.0.0
# py4j                              0.10.9.7
# pyarrow                           14.0.2
# pyarrow-hotfix                    0.6
# pyasn1                            0.6.0
# pyasn1_modules                    0.4.0
# pycocotools                       2.0.8
# pycparser                         2.22
# pydantic                          2.8.2
# pydantic_core                     2.20.1
# pydata-google-auth                1.8.2
# pydot                             1.4.2
# pydot-ng                          2.0.0
# pydotplus                         2.0.2
# PyDrive                           1.3.1
# PyDrive2                          1.6.3
# pyerfa                            2.0.1.4
# pygame                            2.6.0
# Pygments                          2.16.1
# PyGObject                         3.42.1
# PyJWT                             2.8.0
# pylatexenc                        2.10
# pymc                              5.10.4
# pymystem3                         0.2.0
# pynvjitlink-cu12                  0.3.0
# PyOpenGL                          3.1.7
# pyOpenSSL                         24.2.1
# pyparsing                         3.1.2
# pyperclip                         1.9.0
# pyproj                            3.6.1
# pyproject_hooks                   1.1.0
# pyshp                             2.3.1
# PySocks                           1.7.1
# pyspnego                          0.11.1
# pytensor                          2.18.6
# pytest                            7.4.4
# python-apt                        2.4.0
# python-box                        7.2.0
# python-dateutil                   2.8.2
# python-louvain                    0.16
# python-slugify                    8.0.4
# python-utils                      3.8.2
# pytz                              2024.1
# pyviz_comms                       3.0.2
# PyYAML                            6.0.1
# pyzmq                             24.0.1
# qdldl                             0.1.7.post4
# qiskit                            1.1.1
# ratelim                           0.1.6
# referencing                       0.35.1
# regex                             2024.5.15
# requests                          2.31.0
# requests_ntlm                     1.3.0
# requests-oauthlib                 1.3.1
# requirements-parser               0.9.0
# retry                             0.9.2
# rich                              13.7.1
# rmm-cu12                          24.4.0
# rpds-py                           0.19.1
# rpy2                              3.4.2
# rsa                               4.9
# rustworkx                         0.15.1
# s3transfer                        0.10.2
# safetensors                       0.4.3
# scikit-image                      0.23.2
# scikit-learn                      1.3.2
# scipy                             1.13.1
# scooby                            0.10.0
# scs                               3.2.6
# seaborn                           0.13.1
# SecretStorage                     3.3.1
# Send2Trash                        1.8.3
# sentencepiece                     0.1.99
# setuptools                        69.5.1
# shapely                           2.0.5
# shellingham                       1.5.4
# simple_parsing                    0.1.5
# six                               1.16.0
# sklearn-pandas                    2.2.0
# smart-open                        7.0.4
# sniffio                           1.3.1
# snowballstemmer                   2.2.0
# snowflake-connector-python        3.12.0
# sortedcontainers                  2.4.0
# soundfile                         0.12.1
# soupsieve                         2.5
# soxr                              0.4.0
# spacy                             3.7.5
# spacy-legacy                      3.0.12
# spacy-loggers                     1.0.5
# Sphinx                            5.0.2
# sphinxcontrib-applehelp           2.0.0
# sphinxcontrib-devhelp             2.0.0
# sphinxcontrib-htmlhelp            2.1.0
# sphinxcontrib-jsmath              1.0.1
# sphinxcontrib-qthelp              2.0.0
# sphinxcontrib-serializinghtml     2.0.0
# SQLAlchemy                        2.0.31
# sqlglot                           20.11.0
# sqlparse                          0.5.1
# srsly                             2.4.8
# stanio                            0.5.1
# statsmodels                       0.14.2
# stevedore                         5.2.0
# StrEnum                           0.4.15
# symengine                         0.11.0
# sympy                             1.13.1
# tables                            3.8.0
# tabulate                          0.9.0
# tbb                               2021.13.0
# tblib                             3.0.0
# tenacity                          9.0.0
# tensorboard                       2.17.0
# tensorboard-data-server           0.7.2
# tensorflow                        2.17.0
# tensorflow-datasets               4.9.6
# tensorflow-hub                    0.16.1
# tensorflow-io-gcs-filesystem      0.37.1
# tensorflow-metadata               1.15.0
# tensorflow-probability            0.24.0
# tensorstore                       0.1.63
# termcolor                         2.4.0
# terminado                         0.18.1
# text-unidecode                    1.3
# textblob                          0.17.1
# tf_keras                          2.17.0
# tf-slim                           1.1.0
# thinc                             8.2.5
# threadpoolctl                     3.5.0
# tifffile                          2024.7.24
# tinycss2                          1.3.0
# tokenizers                        0.19.1
# toml                              0.10.2
# tomli                             2.0.1
# tomlkit                           0.13.0
# toolz                             0.12.1
# torch                             2.3.1+cu121
# torchaudio                        2.3.1+cu121
# torchsummary                      1.5.1
# torchtext                         0.18.0
# torchvision                       0.18.1+cu121
# tornado                           6.3.3
# tqdm                              4.66.4
# traitlets                         5.7.1
# traittypes                        0.2.1
# transformers                      4.42.4
# triton                            2.3.1
# tweepy                            4.14.0
# typeguard                         4.3.0
# typer                             0.12.3
# types-pytz                        2024.1.0.20240417
# types-setuptools                  71.1.0.20240726
# typing_extensions                 4.12.2
# tzdata                            2024.1
# tzlocal                           5.2
# uc-micro-py                       1.0.3
# uritemplate                       4.1.1
# urllib3                           2.2.2
# vega-datasets                     0.9.0
# wadllib                           1.3.6
# wasabi                            1.1.3
# wcwidth                           0.2.13
# weasel                            0.4.1
# webcolors                         24.6.0
# webencodings                      0.5.1
# websocket-client                  1.8.0
# Werkzeug                          3.0.3
# wheel                             0.43.0
# widgetsnbextension                3.6.8
# wordcloud                         1.9.3
# wrapt                             1.16.0
# xarray                            2024.6.0
# xarray-einstats                   0.7.0
# xgboost                           2.1.0
# xlrd                              2.0.1
# xyzservices                       2024.6.0
# yarl                              1.9.4
# yellowbrick                       1.5
# yfinance                          0.2.41
# zict                              3.0.0
# zipp                              3.19.2

# %%
# !pip install setuptools==69.5.1
# Out:
# Requirement already satisfied: setuptools==69.5.1 in /usr/local/lib/python3.10/dist-packages (69.5.1)

# %%
# !pip list
# Out:
# Package                           Version
# --------------------------------- ---------------------
# absl-py                           1.4.0
# accelerate                        0.32.1
# aiohttp                           3.9.5
# aiosignal                         1.3.1
# alabaster                         0.7.16
# albucore                          0.0.12
# albumentations                    1.4.12
# altair                            4.2.2
# amazon-braket-default-simulator   1.26.0
# amazon-braket-schemas             1.22.0
# amazon-braket-sdk                 1.84.0
# annotated-types                   0.7.0
# antlr4-python3-runtime            4.9.2
# anyio                             3.7.1
# argon2-cffi                       23.1.0
# argon2-cffi-bindings              21.2.0
# array_record                      0.5.1
# arviz                             0.18.0
# asn1crypto                        1.5.1
# astropy                           6.1.2
# astropy-iers-data                 0.2024.7.29.0.32.7
# astunparse                        1.6.3
# async-timeout                     4.0.3
# atpublic                          4.1.0
# attrs                             23.2.0
# audioread                         3.0.1
# autograd                          1.6.2
# Babel                             2.15.0
# backcall                          0.2.0
# backoff                           2.2.1
# backports.entry-points-selectable 1.3.0
# beautifulsoup4                    4.12.3
# bidict                            0.23.1
# bigframes                         1.11.1
# bleach                            6.1.0
# blinker                           1.4
# blis                              0.7.11
# blosc2                            2.0.0
# bokeh                             3.4.3
# boltons                           24.0.0
# boto3                             1.34.151
# botocore                          1.34.151
# bqplot                            0.12.43
# branca                            0.7.2
# build                             1.2.1
# CacheControl                      0.14.0
# cachetools                        5.4.0
# catalogue                         2.0.10
# certifi                           2024.7.4
# cffi                              1.16.0
# chardet                           5.2.0
# charset-normalizer                3.3.2
# chex                              0.1.86
# clarabel                          0.9.0
# click                             8.1.7
# click-plugins                     1.1.1
# cligj                             0.7.2
# cloudpathlib                      0.18.1
# cloudpickle                       2.2.1
# cmake                             3.30.1
# cmdstanpy                         1.2.4
# colorcet                          3.1.0
# colorlover                        0.3.0
# colour                            0.1.5
# community                         1.0.0b1
# confection                        0.1.5
# cons                              0.4.6
# contextlib2                       21.6.0
# contourpy                         1.2.1
# cryptography                      42.0.8
# cuda-python                       12.2.1
# cudf-cu12                         24.4.1
# cufflinks                         0.17.3
# cupy-cuda12x                      12.2.0
# cvxopt                            1.3.2
# cvxpy                             1.5.2
# cycler                            0.12.1
# cymem                             2.0.8
# Cython                            3.0.10
# dask                              2024.7.1
# datascience                       0.17.6
# db-dtypes                         1.2.0
# dbus-python                       1.2.18
# debugpy                           1.6.6
# decorator                         5.1.1
# defusedxml                        0.7.1
# dill                              0.3.8
# distributed                       2024.7.1
# distro                            1.7.0
# dlib                              19.24.2
# dm-tree                           0.1.8
# docstring_parser                  0.16
# docutils                          0.18.1
# dopamine_rl                       4.0.9
# duckdb                            0.10.3
# earthengine-api                   0.1.414
# easydict                          1.13
# ecos                              2.0.14
# editdistance                      0.8.1
# eerepr                            0.0.4
# en-core-web-sm                    3.7.1
# entrypoints                       0.4
# et-xmlfile                        1.1.0
# etils                             1.7.0
# etuples                           0.3.9
# eval_type_backport                0.2.0
# exceptiongroup                    1.2.2
# fastai                            2.7.15
# fastcore                          1.5.55
# fastdownload                      0.0.7
# fastjsonschema                    2.20.0
# fastprogress                      1.0.3
# fastrlock                         0.8.2
# filelock                          3.15.4
# fiona                             1.9.6
# firebase-admin                    6.5.0
# Flask                             2.2.5
# flatbuffers                       24.3.25
# flax                              0.8.4
# folium                            0.17.0
# fonttools                         4.53.1
# frozendict                        2.4.4
# frozenlist                        1.4.1
# fsspec                            2024.6.1
# future                            1.0.0
# gast                              0.6.0
# gcsfs                             2024.6.1
# GDAL                              3.6.4
# gdown                             5.1.0
# geemap                            0.33.1
# gensim                            4.3.3
# geocoder                          1.38.1
# geographiclib                     2.0
# geopandas                         0.14.4
# geopy                             2.4.1
# gin-config                        0.5.0
# glob2                             0.7
# google                            2.0.3
# google-ai-generativelanguage      0.6.6
# google-api-core                   2.19.1
# google-api-python-client          2.137.0
# google-auth                       2.27.0
# google-auth-httplib2              0.2.0
# google-auth-oauthlib              1.2.1
# google-cloud-aiplatform           1.59.0
# google-cloud-bigquery             3.25.0
# google-cloud-bigquery-connection  1.15.4
# google-cloud-bigquery-storage     2.25.0
# google-cloud-bigtable             2.25.0
# google-cloud-core                 2.4.1
# google-cloud-datastore            2.19.0
# google-cloud-firestore            2.16.1
# google-cloud-functions            1.16.4
# google-cloud-iam                  2.15.1
# google-cloud-language             2.13.4
# google-cloud-pubsub               2.23.0
# google-cloud-resource-manager     1.12.4
# google-cloud-storage              2.8.0
# google-cloud-translate            3.15.4
# google-colab                      1.0.0
# google-crc32c                     1.5.0
# google-generativeai               0.7.2
# google-pasta                      0.2.0
# google-resumable-media            2.7.1
# googleapis-common-protos          1.63.2
# googledrivedownloader             0.4
# graphviz                          0.20.3
# greenlet                          3.0.3
# grpc-google-iam-v1                0.13.1
# grpcio                            1.64.1
# grpcio-status                     1.48.2
# gspread                           6.0.2
# gspread-dataframe                 3.3.1
# gym                               0.25.2
# gym-notices                       0.0.8
# h5netcdf                          1.3.0
# h5py                              3.11.0
# holidays                          0.53
# holoviews                         1.18.3
# html5lib                          1.1
# httpimport                        1.3.1
# httplib2                          0.22.0
# huggingface-hub                   0.23.5
# humanize                          4.10.0
# hyperopt                          0.2.7
# ibis-framework                    8.0.0
# ibm-cloud-sdk-core                3.20.4
# ibm-platform-services             0.55.2
# idna                              3.7
# imageio                           2.34.2
# imageio-ffmpeg                    0.5.1
# imagesize                         1.4.1
# imbalanced-learn                  0.12.3
# imgaug                            0.4.0
# immutabledict                     4.2.0
# importlib_metadata                8.2.0
# importlib_resources               6.4.0
# imutils                           0.5.4
# inflect                           7.3.1
# iniconfig                         2.0.0
# intel-cmplr-lib-ur                2024.2.0
# intel-openmp                      2024.2.0
# ipyevents                         2.0.2
# ipyfilechooser                    0.6.0
# ipykernel                         5.5.6
# ipyleaflet                        0.18.2
# ipyparallel                       8.8.0
# ipython                           7.34.0
# ipython-genutils                  0.2.0
# ipython-sql                       0.5.0
# ipytree                           0.2.2
# ipywidgets                        7.7.1
# itsdangerous                      2.2.0
# jax                               0.4.26
# jaxlib                            0.4.26+cuda12.cudnn89
# jedi                              0.19.1
# jeepney                           0.7.1
# jellyfish                         1.1.0
# jieba                             0.42.1
# Jinja2                            3.1.4
# jmespath                          1.0.1
# joblib                            1.4.2
# jsonpickle                        3.2.2
# jsonschema                        4.23.0
# jsonschema-specifications         2023.12.1
# jupyter-client                    6.1.12
# jupyter-console                   6.1.0
# jupyter_core                      5.7.2
# jupyter-server                    1.24.0
# jupyterlab_pygments               0.3.0
# jupyterlab_widgets                3.0.11
# kaggle                            1.6.17
# kagglehub                         0.2.8
# keras                             3.4.1
# keyring                           23.5.0
# kiwisolver                        1.4.5
# langcodes                         3.4.0
# language_data                     1.2.0
# launchpadlib                      1.10.16
# lazr.restfulclient                0.14.4
# lazr.uri                          1.0.6
# lazy_loader                       0.4
# libclang                          18.1.1
# librosa                           0.10.2.post1
# lightgbm                          4.4.0
# linkify-it-py                     2.0.3
# llvmlite                          0.43.0
# locket                            1.0.0
# logical-unification               0.4.6
# lxml                              4.9.4
# malloy                            2024.1089
# marisa-trie                       1.2.0
# Markdown                          3.6
# markdown-it-py                    3.0.0
# MarkupSafe                        2.1.5
# matplotlib                        3.7.1
# matplotlib-inline                 0.1.7
# matplotlib-venn                   0.11.10
# mdit-py-plugins                   0.4.1
# mdurl                             0.1.2
# miniKanren                        1.0.3
# missingno                         0.5.2
# mistune                           0.8.4
# mizani                            0.9.3
# mkl                               2024.2.0
# ml-dtypes                         0.4.0
# mlxtend                           0.23.1
# more-itertools                    10.3.0
# moviepy                           1.0.3
# mpmath                            1.3.0
# msgpack                           1.0.8
# multidict                         6.0.5
# multipledispatch                  1.0.0
# multitasking                      0.0.11
# murmurhash                        1.0.10
# music21                           9.1.0
# mypy-extensions                   1.0.0
# namex                             0.0.8
# natsort                           8.4.0
# nbclassic                         1.1.0
# nbclient                          0.10.0
# nbconvert                         6.5.4
# nbformat                          5.10.4
# nest-asyncio                      1.6.0
# networkx                          3.3
# nibabel                           5.0.1
# nltk                              3.8.1
# notebook                          6.5.5
# notebook_shim                     0.2.4
# numba                             0.60.0
# numexpr                           2.10.1
# numpy                             1.26.4
# nvtx                              0.2.10
# oauth2client                      4.1.3
# oauthlib                          3.2.2
# opencv-contrib-python             4.10.0.84
# opencv-python                     4.10.0.84
# opencv-python-headless            4.10.0.84
# openpulse                         0.5.0
# openpyxl                          3.1.5
# openqasm3                         1.0.0
# opt-einsum                        3.3.0
# optax                             0.2.2
# optree                            0.12.1
# oqpy                              0.3.6
# orbax-checkpoint                  0.5.23
# osqp                              0.6.7.post0
# packaging                         24.1
# pandas                            2.1.4
# pandas-datareader                 0.10.0
# pandas-gbq                        0.19.2
# pandas-stubs                      2.1.4.231227
# pandocfilters                     1.5.1
# panel                             1.4.4
# param                             2.1.1
# parso                             0.8.4
# parsy                             2.1
# partd                             1.4.2
# pathlib                           1.0.1
# patsy                             0.5.6
# pbr                               6.0.0
# peewee                            3.17.6
# pexpect                           4.9.0
# pickleshare                       0.7.5
# Pillow                            9.4.0
# pip                               24.1.2
# pip-tools                         7.4.1
# platformdirs                      4.2.2
# plotly                            5.15.0
# plotnine                          0.12.4
# pluggy                            1.5.0
# ply                               3.11
# polars                            0.20.2
# pooch                             1.8.2
# portpicker                        1.5.2
# prefetch_generator                1.0.3
# preshed                           3.0.9
# prettytable                       3.10.2
# proglog                           0.1.10
# progressbar2                      4.2.0
# prometheus_client                 0.20.0
# promise                           2.3
# prompt_toolkit                    3.0.47
# prophet                           1.1.5
# proto-plus                        1.24.0
# protobuf                          3.20.3
# psutil                            5.9.5
# psycopg2                          2.9.9
# ptyprocess                        0.7.0
# py                                1.11.0
# py-cpuinfo                        9.0.0
# py4j                              0.10.9.7
# pyarrow                           14.0.2
# pyarrow-hotfix                    0.6
# pyasn1                            0.6.0
# pyasn1_modules                    0.4.0
# pycocotools                       2.0.8
# pycparser                         2.22
# pydantic                          2.8.2
# pydantic_core                     2.20.1
# pydata-google-auth                1.8.2
# pydot                             1.4.2
# pydot-ng                          2.0.0
# pydotplus                         2.0.2
# PyDrive                           1.3.1
# PyDrive2                          1.6.3
# pyerfa                            2.0.1.4
# pygame                            2.6.0
# Pygments                          2.16.1
# PyGObject                         3.42.1
# PyJWT                             2.8.0
# pylatexenc                        2.10
# pymc                              5.10.4
# pymystem3                         0.2.0
# pynvjitlink-cu12                  0.3.0
# PyOpenGL                          3.1.7
# pyOpenSSL                         24.2.1
# pyparsing                         3.1.2
# pyperclip                         1.9.0
# pyproj                            3.6.1
# pyproject_hooks                   1.1.0
# pyshp                             2.3.1
# PySocks                           1.7.1
# pyspnego                          0.11.1
# pytensor                          2.18.6
# pytest                            7.4.4
# python-apt                        2.4.0
# python-box                        7.2.0
# python-dateutil                   2.8.2
# python-louvain                    0.16
# python-slugify                    8.0.4
# python-utils                      3.8.2
# pytz                              2024.1
# pyviz_comms                       3.0.2
# PyYAML                            6.0.1
# pyzmq                             24.0.1
# qdldl                             0.1.7.post4
# qiskit                            1.1.1
# qiskit-aer                        0.14.2
# qiskit-braket-provider            0.4.0
# qiskit-ibm-runtime                0.25.0
# qiskit-ionq                       0.4.7
# ratelim                           0.1.6
# referencing                       0.35.1
# regex                             2024.5.15
# requests                          2.31.0
# requests_ntlm                     1.3.0
# requests-oauthlib                 1.3.1
# requirements-parser               0.9.0
# retry                             0.9.2
# rich                              13.7.1
# rmm-cu12                          24.4.0
# rpds-py                           0.19.1
# rpy2                              3.4.2
# rsa                               4.9
# rustworkx                         0.15.1
# s3transfer                        0.10.2
# safetensors                       0.4.3
# scikit-image                      0.23.2
# scikit-learn                      1.3.2
# scipy                             1.13.1
# scooby                            0.10.0
# scs                               3.2.6
# seaborn                           0.13.1
# SecretStorage                     3.3.1
# Send2Trash                        1.8.3
# sentencepiece                     0.1.99
# setuptools                        69.5.1
# shapely                           2.0.5
# shellingham                       1.5.4
# simple_parsing                    0.1.5
# six                               1.16.0
# sklearn-pandas                    2.2.0
# smart-open                        7.0.4
# sniffio                           1.3.1
# snowballstemmer                   2.2.0
# snowflake-connector-python        3.12.0
# sortedcontainers                  2.4.0
# soundfile                         0.12.1
# soupsieve                         2.5
# soxr                              0.4.0
# spacy                             3.7.5
# spacy-legacy                      3.0.12
# spacy-loggers                     1.0.5
# Sphinx                            5.0.2
# sphinxcontrib-applehelp           2.0.0
# sphinxcontrib-devhelp             2.0.0
# sphinxcontrib-htmlhelp            2.1.0
# sphinxcontrib-jsmath              1.0.1
# sphinxcontrib-qthelp              2.0.0
# sphinxcontrib-serializinghtml     2.0.0
# SQLAlchemy                        2.0.31
# sqlglot                           20.11.0
# sqlparse                          0.5.1
# srsly                             2.4.8
# stanio                            0.5.1
# statsmodels                       0.14.2
# stevedore                         5.2.0
# StrEnum                           0.4.15
# symengine                         0.11.0
# sympy                             1.13.1
# tables                            3.8.0
# tabulate                          0.9.0
# tbb                               2021.13.0
# tblib                             3.0.0
# tenacity                          9.0.0
# tensorboard                       2.17.0
# tensorboard-data-server           0.7.2
# tensorflow                        2.17.0
# tensorflow-datasets               4.9.6
# tensorflow-hub                    0.16.1
# tensorflow-io-gcs-filesystem      0.37.1
# tensorflow-metadata               1.15.0
# tensorflow-probability            0.24.0
# tensorstore                       0.1.63
# termcolor                         2.4.0
# terminado                         0.18.1
# text-unidecode                    1.3
# textblob                          0.17.1
# tf_keras                          2.17.0
# tf-slim                           1.1.0
# thinc                             8.2.5
# threadpoolctl                     3.5.0
# tifffile                          2024.7.24
# tinycss2                          1.3.0
# tokenizers                        0.19.1
# toml                              0.10.2
# tomli                             2.0.1
# tomlkit                           0.13.0
# toolz                             0.12.1
# torch                             2.3.1+cu121
# torchaudio                        2.3.1+cu121
# torchsummary                      1.5.1
# torchtext                         0.18.0
# torchvision                       0.18.1+cu121
# tornado                           6.3.3
# tqdm                              4.66.4
# traitlets                         5.7.1
# traittypes                        0.2.1
# transformers                      4.42.4
# triton                            2.3.1
# tweepy                            4.14.0
# typeguard                         4.3.0
# typer                             0.12.3
# types-pytz                        2024.1.0.20240417
# types-setuptools                  71.1.0.20240726
# typing_extensions                 4.12.2
# tzdata                            2024.1
# tzlocal                           5.2
# uc-micro-py                       1.0.3
# uritemplate                       4.1.1
# urllib3                           2.2.2
# vega-datasets                     0.9.0
# wadllib                           1.3.6
# wasabi                            1.1.3
# wcwidth                           0.2.13
# weasel                            0.4.1
# webcolors                         24.6.0
# webencodings                      0.5.1
# websocket-client                  1.8.0
# Werkzeug                          3.0.3
# wheel                             0.43.0
# widgetsnbextension                3.6.8
# wordcloud                         1.9.3
# wrapt                             1.16.0
# xarray                            2024.6.0
# xarray-einstats                   0.7.0
# xgboost                           2.1.0
# xlrd                              2.0.1
# xyzservices                       2024.6.0
# yarl                              1.9.4
# yellowbrick                       1.5
# yfinance                          0.2.41
# zict                              3.0.0
# zipp                              3.19.2

# %%
# !pip install qiskit_ibm_runtime
# Out:
# Collecting qiskit_ibm_runtime
#   Downloading qiskit_ibm_runtime-0.25.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: requests>=2.19 in /usr/local/lib/python3.10/dist-packages (from qiskit_ibm_runtime) (2.31.0)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from qiskit_ibm_runtime) (1.3.0)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.10/dist-packages (from qiskit_ibm_runtime) (1.26.4)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from qiskit_ibm_runtime) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from qiskit_ibm_runtime) (2.8.2)
# Requirement already satisfied: websocket-client>=1.5.1 in /usr/local/lib/python3.10/dist-packages (from qiskit_ibm_runtime) (1.8.0)
# Requirement already satisfied: ibm-platform-services>=0.22.6 in /usr/local/lib/python3.10/dist-packages (from qiskit_ibm_runtime) (0.55.2)
# Requirement already satisfied: pydantic>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from qiskit_ibm_runtime) (2.8.2)
# Requirement already satisfied: qiskit>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from qiskit_ibm_runtime) (1.1.1)
# Requirement already satisfied: ibm-cloud-sdk-core<4.0.0,>=3.20.4 in /usr/local/lib/python3.10/dist-packages (from ibm-platform-services>=0.22.6->qiskit_ibm_runtime) (3.20.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.5.0->qiskit_ibm_runtime) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.5.0->qiskit_ibm_runtime) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.5.0->qiskit_ibm_runtime) (4.12.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.0->qiskit_ibm_runtime) (1.16.0)
# Requirement already satisfied: rustworkx>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from qiskit>=1.1.0->qiskit_ibm_runtime) (0.15.1)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.10/dist-packages (from qiskit>=1.1.0->qiskit_ibm_runtime) (1.13.1)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.10/dist-packages (from qiskit>=1.1.0->qiskit_ibm_runtime) (1.13.1)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.10/dist-packages (from qiskit>=1.1.0->qiskit_ibm_runtime) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from qiskit>=1.1.0->qiskit_ibm_runtime) (5.2.0)
# Requirement already satisfied: symengine>=0.11 in /usr/local/lib/python3.10/dist-packages (from qiskit>=1.1.0->qiskit_ibm_runtime) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19->qiskit_ibm_runtime) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19->qiskit_ibm_runtime) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19->qiskit_ibm_runtime) (2024.7.4)
# Requirement already satisfied: cryptography>=1.3 in /usr/local/lib/python3.10/dist-packages (from requests-ntlm>=1.1.0->qiskit_ibm_runtime) (42.0.8)
# Requirement already satisfied: pyspnego>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from requests-ntlm>=1.1.0->qiskit_ibm_runtime) (0.11.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_runtime) (1.16.0)
# Requirement already satisfied: PyJWT<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from ibm-cloud-sdk-core<4.0.0,>=3.20.4->ibm-platform-services>=0.22.6->qiskit_ibm_runtime) (2.8.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from stevedore>=3.0.0->qiskit>=1.1.0->qiskit_ibm_runtime) (6.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.3->qiskit>=1.1.0->qiskit_ibm_runtime) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_runtime) (2.22)
# Downloading qiskit_ibm_runtime-0.25.0-py3-none-any.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 19.3 MB/s eta 0:00:00
# Installing collected packages: qiskit_ibm_runtime
# Successfully installed qiskit_ibm_runtime-0.25.0

# %%
# !pip install ibm-platform-services==0.55.2
#ibm-cloud-sdk-core-3.20.4 ibm-platform-services-0.55.2 urllib3-2.2.
# Out:
# Requirement already satisfied: ibm-platform-services==0.55.2 in /usr/local/lib/python3.10/dist-packages (0.55.2)
# Requirement already satisfied: ibm-cloud-sdk-core<4.0.0,>=3.20.4 in /usr/local/lib/python3.10/dist-packages (from ibm-platform-services==0.55.2) (3.20.4)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from ibm-cloud-sdk-core<4.0.0,>=3.20.4->ibm-platform-services==0.55.2) (2.31.0)
# Requirement already satisfied: urllib3<3.0.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from ibm-cloud-sdk-core<4.0.0,>=3.20.4->ibm-platform-services==0.55.2) (2.2.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from ibm-cloud-sdk-core<4.0.0,>=3.20.4->ibm-platform-services==0.55.2) (2.8.2)
# Requirement already satisfied: PyJWT<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from ibm-cloud-sdk-core<4.0.0,>=3.20.4->ibm-platform-services==0.55.2) (2.8.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.8.2->ibm-cloud-sdk-core<4.0.0,>=3.20.4->ibm-platform-services==0.55.2) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->ibm-cloud-sdk-core<4.0.0,>=3.20.4->ibm-platform-services==0.55.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->ibm-cloud-sdk-core<4.0.0,>=3.20.4->ibm-platform-services==0.55.2) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->ibm-cloud-sdk-core<4.0.0,>=3.20.4->ibm-platform-services==0.55.2) (2024.7.4)

# %%
#!pip install qiskit_ibm_runtime --no-cache-dir
#qiskit-1.1.1 qiskit_ibm_runtime-0.25.0

# %%
# !pip uninstall qiskit_braket_provider -y
# Out:
# WARNING: Skipping qiskit_braket_provider as it is not installed.

# %%
# !pip install pylatexenc
# Out:
# Requirement already satisfied: pylatexenc in /usr/local/lib/python3.10/dist-packages (2.10)

# %%
# !pip install ipykernel
# Out:
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (5.5.6)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipykernel) (0.2.0)
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (7.34.0)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (5.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (6.3.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel) (69.5.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel) (5.1.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel) (4.9.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel) (5.7.2)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel) (24.0.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel) (2.8.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel) (4.2.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=5.0.0->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.1->jupyter-client->ipykernel) (1.16.0)

# %%
# !pip install qiskit_aer
# Out:
# Collecting qiskit_aer
#   Using cached qiskit_aer-0.14.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: qiskit>=0.45.2 in /usr/local/lib/python3.10/dist-packages (from qiskit_aer) (1.1.1)
# Requirement already satisfied: numpy>=1.16.3 in /usr/local/lib/python3.10/dist-packages (from qiskit_aer) (1.26.4)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from qiskit_aer) (1.13.1)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.10/dist-packages (from qiskit_aer) (5.9.5)
# Requirement already satisfied: rustworkx>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from qiskit>=0.45.2->qiskit_aer) (0.15.1)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.10/dist-packages (from qiskit>=0.45.2->qiskit_aer) (1.13.1)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.10/dist-packages (from qiskit>=0.45.2->qiskit_aer) (0.3.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from qiskit>=0.45.2->qiskit_aer) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from qiskit>=0.45.2->qiskit_aer) (5.2.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from qiskit>=0.45.2->qiskit_aer) (4.12.2)
# Requirement already satisfied: symengine>=0.11 in /usr/local/lib/python3.10/dist-packages (from qiskit>=0.45.2->qiskit_aer) (0.11.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.0->qiskit>=0.45.2->qiskit_aer) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from stevedore>=3.0.0->qiskit>=0.45.2->qiskit_aer) (6.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.3->qiskit>=0.45.2->qiskit_aer) (1.3.0)
# Using cached qiskit_aer-0.14.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
# Installing collected packages: qiskit_aer
# Successfully installed qiskit_aer-0.14.2

# %%
# !pip list
# Out:
# Package                           Version
# --------------------------------- ---------------------
# absl-py                           1.4.0
# accelerate                        0.32.1
# aiohttp                           3.9.5
# aiosignal                         1.3.1
# alabaster                         0.7.16
# albucore                          0.0.12
# albumentations                    1.4.12
# altair                            4.2.2
# amazon-braket-default-simulator   1.26.0
# amazon-braket-schemas             1.22.0
# amazon-braket-sdk                 1.84.0
# annotated-types                   0.7.0
# antlr4-python3-runtime            4.9.2
# anyio                             3.7.1
# argon2-cffi                       23.1.0
# argon2-cffi-bindings              21.2.0
# array_record                      0.5.1
# arviz                             0.18.0
# asn1crypto                        1.5.1
# astropy                           6.1.2
# astropy-iers-data                 0.2024.7.29.0.32.7
# astunparse                        1.6.3
# async-timeout                     4.0.3
# atpublic                          4.1.0
# attrs                             23.2.0
# audioread                         3.0.1
# autograd                          1.6.2
# Babel                             2.15.0
# backcall                          0.2.0
# backoff                           2.2.1
# backports.entry-points-selectable 1.3.0
# beautifulsoup4                    4.12.3
# bidict                            0.23.1
# bigframes                         1.11.1
# bleach                            6.1.0
# blinker                           1.4
# blis                              0.7.11
# blosc2                            2.0.0
# bokeh                             3.4.3
# boltons                           24.0.0
# boto3                             1.34.151
# botocore                          1.34.151
# bqplot                            0.12.43
# branca                            0.7.2
# build                             1.2.1
# CacheControl                      0.14.0
# cachetools                        5.4.0
# catalogue                         2.0.10
# certifi                           2024.7.4
# cffi                              1.16.0
# chardet                           5.2.0
# charset-normalizer                3.3.2
# chex                              0.1.86
# clarabel                          0.9.0
# click                             8.1.7
# click-plugins                     1.1.1
# cligj                             0.7.2
# cloudpathlib                      0.18.1
# cloudpickle                       2.2.1
# cmake                             3.30.1
# cmdstanpy                         1.2.4
# colorcet                          3.1.0
# colorlover                        0.3.0
# colour                            0.1.5
# community                         1.0.0b1
# confection                        0.1.5
# cons                              0.4.6
# contextlib2                       21.6.0
# contourpy                         1.2.1
# cryptography                      42.0.8
# cuda-python                       12.2.1
# cudf-cu12                         24.4.1
# cufflinks                         0.17.3
# cupy-cuda12x                      12.2.0
# cvxopt                            1.3.2
# cvxpy                             1.5.2
# cycler                            0.12.1
# cymem                             2.0.8
# Cython                            3.0.10
# dask                              2024.7.1
# datascience                       0.17.6
# db-dtypes                         1.2.0
# dbus-python                       1.2.18
# debugpy                           1.6.6
# decorator                         5.1.1
# defusedxml                        0.7.1
# dill                              0.3.8
# distributed                       2024.7.1
# distro                            1.7.0
# dlib                              19.24.2
# dm-tree                           0.1.8
# docstring_parser                  0.16
# docutils                          0.18.1
# dopamine_rl                       4.0.9
# duckdb                            0.10.3
# earthengine-api                   0.1.414
# easydict                          1.13
# ecos                              2.0.14
# editdistance                      0.8.1
# eerepr                            0.0.4
# en-core-web-sm                    3.7.1
# entrypoints                       0.4
# et-xmlfile                        1.1.0
# etils                             1.7.0
# etuples                           0.3.9
# eval_type_backport                0.2.0
# exceptiongroup                    1.2.2
# fastai                            2.7.15
# fastcore                          1.5.55
# fastdownload                      0.0.7
# fastjsonschema                    2.20.0
# fastprogress                      1.0.3
# fastrlock                         0.8.2
# filelock                          3.15.4
# fiona                             1.9.6
# firebase-admin                    6.5.0
# Flask                             2.2.5
# flatbuffers                       24.3.25
# flax                              0.8.4
# folium                            0.17.0
# fonttools                         4.53.1
# frozendict                        2.4.4
# frozenlist                        1.4.1
# fsspec                            2024.6.1
# future                            1.0.0
# gast                              0.6.0
# gcsfs                             2024.6.1
# GDAL                              3.6.4
# gdown                             5.1.0
# geemap                            0.33.1
# gensim                            4.3.3
# geocoder                          1.38.1
# geographiclib                     2.0
# geopandas                         0.14.4
# geopy                             2.4.1
# gin-config                        0.5.0
# glob2                             0.7
# google                            2.0.3
# google-ai-generativelanguage      0.6.6
# google-api-core                   2.19.1
# google-api-python-client          2.137.0
# google-auth                       2.27.0
# google-auth-httplib2              0.2.0
# google-auth-oauthlib              1.2.1
# google-cloud-aiplatform           1.59.0
# google-cloud-bigquery             3.25.0
# google-cloud-bigquery-connection  1.15.4
# google-cloud-bigquery-storage     2.25.0
# google-cloud-bigtable             2.25.0
# google-cloud-core                 2.4.1
# google-cloud-datastore            2.19.0
# google-cloud-firestore            2.16.1
# google-cloud-functions            1.16.4
# google-cloud-iam                  2.15.1
# google-cloud-language             2.13.4
# google-cloud-pubsub               2.23.0
# google-cloud-resource-manager     1.12.4
# google-cloud-storage              2.8.0
# google-cloud-translate            3.15.4
# google-colab                      1.0.0
# google-crc32c                     1.5.0
# google-generativeai               0.7.2
# google-pasta                      0.2.0
# google-resumable-media            2.7.1
# googleapis-common-protos          1.63.2
# googledrivedownloader             0.4
# graphviz                          0.20.3
# greenlet                          3.0.3
# grpc-google-iam-v1                0.13.1
# grpcio                            1.64.1
# grpcio-status                     1.48.2
# gspread                           6.0.2
# gspread-dataframe                 3.3.1
# gym                               0.25.2
# gym-notices                       0.0.8
# h5netcdf                          1.3.0
# h5py                              3.11.0
# holidays                          0.53
# holoviews                         1.18.3
# html5lib                          1.1
# httpimport                        1.3.1
# httplib2                          0.22.0
# huggingface-hub                   0.23.5
# humanize                          4.10.0
# hyperopt                          0.2.7
# ibis-framework                    8.0.0
# ibm-cloud-sdk-core                3.20.4
# ibm-platform-services             0.55.2
# idna                              3.7
# imageio                           2.34.2
# imageio-ffmpeg                    0.5.1
# imagesize                         1.4.1
# imbalanced-learn                  0.12.3
# imgaug                            0.4.0
# immutabledict                     4.2.0
# importlib_metadata                8.2.0
# importlib_resources               6.4.0
# imutils                           0.5.4
# inflect                           7.3.1
# iniconfig                         2.0.0
# intel-cmplr-lib-ur                2024.2.0
# intel-openmp                      2024.2.0
# ipyevents                         2.0.2
# ipyfilechooser                    0.6.0
# ipykernel                         5.5.6
# ipyleaflet                        0.18.2
# ipyparallel                       8.8.0
# ipython                           7.34.0
# ipython-genutils                  0.2.0
# ipython-sql                       0.5.0
# ipytree                           0.2.2
# ipywidgets                        7.7.1
# itsdangerous                      2.2.0
# jax                               0.4.26
# jaxlib                            0.4.26+cuda12.cudnn89
# jedi                              0.19.1
# jeepney                           0.7.1
# jellyfish                         1.1.0
# jieba                             0.42.1
# Jinja2                            3.1.4
# jmespath                          1.0.1
# joblib                            1.4.2
# jsonpickle                        3.2.2
# jsonschema                        4.23.0
# jsonschema-specifications         2023.12.1
# jupyter-client                    6.1.12
# jupyter-console                   6.1.0
# jupyter_core                      5.7.2
# jupyter-server                    1.24.0
# jupyterlab_pygments               0.3.0
# jupyterlab_widgets                3.0.11
# kaggle                            1.6.17
# kagglehub                         0.2.8
# keras                             3.4.1
# keyring                           23.5.0
# kiwisolver                        1.4.5
# langcodes                         3.4.0
# language_data                     1.2.0
# launchpadlib                      1.10.16
# lazr.restfulclient                0.14.4
# lazr.uri                          1.0.6
# lazy_loader                       0.4
# libclang                          18.1.1
# librosa                           0.10.2.post1
# lightgbm                          4.4.0
# linkify-it-py                     2.0.3
# llvmlite                          0.43.0
# locket                            1.0.0
# logical-unification               0.4.6
# lxml                              4.9.4
# malloy                            2024.1089
# marisa-trie                       1.2.0
# Markdown                          3.6
# markdown-it-py                    3.0.0
# MarkupSafe                        2.1.5
# matplotlib                        3.7.1
# matplotlib-inline                 0.1.7
# matplotlib-venn                   0.11.10
# mdit-py-plugins                   0.4.1
# mdurl                             0.1.2
# miniKanren                        1.0.3
# missingno                         0.5.2
# mistune                           0.8.4
# mizani                            0.9.3
# mkl                               2024.2.0
# ml-dtypes                         0.4.0
# mlxtend                           0.23.1
# more-itertools                    10.3.0
# moviepy                           1.0.3
# mpmath                            1.3.0
# msgpack                           1.0.8
# multidict                         6.0.5
# multipledispatch                  1.0.0
# multitasking                      0.0.11
# murmurhash                        1.0.10
# music21                           9.1.0
# mypy-extensions                   1.0.0
# namex                             0.0.8
# natsort                           8.4.0
# nbclassic                         1.1.0
# nbclient                          0.10.0
# nbconvert                         6.5.4
# nbformat                          5.10.4
# nest-asyncio                      1.6.0
# networkx                          3.3
# nibabel                           5.0.1
# nltk                              3.8.1
# notebook                          6.5.5
# notebook_shim                     0.2.4
# numba                             0.60.0
# numexpr                           2.10.1
# numpy                             1.26.4
# nvtx                              0.2.10
# oauth2client                      4.1.3
# oauthlib                          3.2.2
# opencv-contrib-python             4.10.0.84
# opencv-python                     4.10.0.84
# opencv-python-headless            4.10.0.84
# openpulse                         0.5.0
# openpyxl                          3.1.5
# openqasm3                         1.0.0
# opt-einsum                        3.3.0
# optax                             0.2.2
# optree                            0.12.1
# oqpy                              0.3.6
# orbax-checkpoint                  0.5.23
# osqp                              0.6.7.post0
# packaging                         24.1
# pandas                            2.1.4
# pandas-datareader                 0.10.0
# pandas-gbq                        0.19.2
# pandas-stubs                      2.1.4.231227
# pandocfilters                     1.5.1
# panel                             1.4.4
# param                             2.1.1
# parso                             0.8.4
# parsy                             2.1
# partd                             1.4.2
# pathlib                           1.0.1
# patsy                             0.5.6
# pbr                               6.0.0
# peewee                            3.17.6
# pexpect                           4.9.0
# pickleshare                       0.7.5
# Pillow                            9.4.0
# pip                               24.1.2
# pip-tools                         7.4.1
# platformdirs                      4.2.2
# plotly                            5.15.0
# plotnine                          0.12.4
# pluggy                            1.5.0
# ply                               3.11
# polars                            0.20.2
# pooch                             1.8.2
# portpicker                        1.5.2
# prefetch_generator                1.0.3
# preshed                           3.0.9
# prettytable                       3.10.2
# proglog                           0.1.10
# progressbar2                      4.2.0
# prometheus_client                 0.20.0
# promise                           2.3
# prompt_toolkit                    3.0.47
# prophet                           1.1.5
# proto-plus                        1.24.0
# protobuf                          3.20.3
# psutil                            5.9.5
# psycopg2                          2.9.9
# ptyprocess                        0.7.0
# py                                1.11.0
# py-cpuinfo                        9.0.0
# py4j                              0.10.9.7
# pyarrow                           14.0.2
# pyarrow-hotfix                    0.6
# pyasn1                            0.6.0
# pyasn1_modules                    0.4.0
# pycocotools                       2.0.8
# pycparser                         2.22
# pydantic                          2.8.2
# pydantic_core                     2.20.1
# pydata-google-auth                1.8.2
# pydot                             1.4.2
# pydot-ng                          2.0.0
# pydotplus                         2.0.2
# PyDrive                           1.3.1
# PyDrive2                          1.6.3
# pyerfa                            2.0.1.4
# pygame                            2.6.0
# Pygments                          2.16.1
# PyGObject                         3.42.1
# PyJWT                             2.8.0
# pylatexenc                        2.10
# pymc                              5.10.4
# pymystem3                         0.2.0
# pynvjitlink-cu12                  0.3.0
# PyOpenGL                          3.1.7
# pyOpenSSL                         24.2.1
# pyparsing                         3.1.2
# pyperclip                         1.9.0
# pyproj                            3.6.1
# pyproject_hooks                   1.1.0
# pyshp                             2.3.1
# PySocks                           1.7.1
# pyspnego                          0.11.1
# pytensor                          2.18.6
# pytest                            7.4.4
# python-apt                        2.4.0
# python-box                        7.2.0
# python-dateutil                   2.8.2
# python-louvain                    0.16
# python-slugify                    8.0.4
# python-utils                      3.8.2
# pytz                              2024.1
# pyviz_comms                       3.0.2
# PyYAML                            6.0.1
# pyzmq                             24.0.1
# qdldl                             0.1.7.post4
# qiskit                            1.1.1
# qiskit-aer                        0.14.2
# qiskit-ibm-runtime                0.25.0
# ratelim                           0.1.6
# referencing                       0.35.1
# regex                             2024.5.15
# requests                          2.31.0
# requests_ntlm                     1.3.0
# requests-oauthlib                 1.3.1
# requirements-parser               0.9.0
# retry                             0.9.2
# rich                              13.7.1
# rmm-cu12                          24.4.0
# rpds-py                           0.19.1
# rpy2                              3.4.2
# rsa                               4.9
# rustworkx                         0.15.1
# s3transfer                        0.10.2
# safetensors                       0.4.3
# scikit-image                      0.23.2
# scikit-learn                      1.3.2
# scipy                             1.13.1
# scooby                            0.10.0
# scs                               3.2.6
# seaborn                           0.13.1
# SecretStorage                     3.3.1
# Send2Trash                        1.8.3
# sentencepiece                     0.1.99
# setuptools                        69.5.1
# shapely                           2.0.5
# shellingham                       1.5.4
# simple_parsing                    0.1.5
# six                               1.16.0
# sklearn-pandas                    2.2.0
# smart-open                        7.0.4
# sniffio                           1.3.1
# snowballstemmer                   2.2.0
# snowflake-connector-python        3.12.0
# sortedcontainers                  2.4.0
# soundfile                         0.12.1
# soupsieve                         2.5
# soxr                              0.4.0
# spacy                             3.7.5
# spacy-legacy                      3.0.12
# spacy-loggers                     1.0.5
# Sphinx                            5.0.2
# sphinxcontrib-applehelp           2.0.0
# sphinxcontrib-devhelp             2.0.0
# sphinxcontrib-htmlhelp            2.1.0
# sphinxcontrib-jsmath              1.0.1
# sphinxcontrib-qthelp              2.0.0
# sphinxcontrib-serializinghtml     2.0.0
# SQLAlchemy                        2.0.31
# sqlglot                           20.11.0
# sqlparse                          0.5.1
# srsly                             2.4.8
# stanio                            0.5.1
# statsmodels                       0.14.2
# stevedore                         5.2.0
# StrEnum                           0.4.15
# symengine                         0.11.0
# sympy                             1.13.1
# tables                            3.8.0
# tabulate                          0.9.0
# tbb                               2021.13.0
# tblib                             3.0.0
# tenacity                          9.0.0
# tensorboard                       2.17.0
# tensorboard-data-server           0.7.2
# tensorflow                        2.17.0
# tensorflow-datasets               4.9.6
# tensorflow-hub                    0.16.1
# tensorflow-io-gcs-filesystem      0.37.1
# tensorflow-metadata               1.15.0
# tensorflow-probability            0.24.0
# tensorstore                       0.1.63
# termcolor                         2.4.0
# terminado                         0.18.1
# text-unidecode                    1.3
# textblob                          0.17.1
# tf_keras                          2.17.0
# tf-slim                           1.1.0
# thinc                             8.2.5
# threadpoolctl                     3.5.0
# tifffile                          2024.7.24
# tinycss2                          1.3.0
# tokenizers                        0.19.1
# toml                              0.10.2
# tomli                             2.0.1
# tomlkit                           0.13.0
# toolz                             0.12.1
# torch                             2.3.1+cu121
# torchaudio                        2.3.1+cu121
# torchsummary                      1.5.1
# torchtext                         0.18.0
# torchvision                       0.18.1+cu121
# tornado                           6.3.3
# tqdm                              4.66.4
# traitlets                         5.7.1
# traittypes                        0.2.1
# transformers                      4.42.4
# triton                            2.3.1
# tweepy                            4.14.0
# typeguard                         4.3.0
# typer                             0.12.3
# types-pytz                        2024.1.0.20240417
# types-setuptools                  71.1.0.20240726
# typing_extensions                 4.12.2
# tzdata                            2024.1
# tzlocal                           5.2
# uc-micro-py                       1.0.3
# uritemplate                       4.1.1
# urllib3                           2.2.2
# vega-datasets                     0.9.0
# wadllib                           1.3.6
# wasabi                            1.1.3
# wcwidth                           0.2.13
# weasel                            0.4.1
# webcolors                         24.6.0
# webencodings                      0.5.1
# websocket-client                  1.8.0
# Werkzeug                          3.0.3
# wheel                             0.43.0
# widgetsnbextension                3.6.8
# wordcloud                         1.9.3
# wrapt                             1.16.0
# xarray                            2024.6.0
# xarray-einstats                   0.7.0
# xgboost                           2.1.0
# xlrd                              2.0.1
# xyzservices                       2024.6.0
# yarl                              1.9.4
# yellowbrick                       1.5
# yfinance                          0.2.41
# zict                              3.0.0
# zipp                              3.19.2

# %%
#!pip install qiskit-terra --no-cache-dir

# %%
import qiskit
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit import QuantumCircuit, QuantumRegister, quantum_info
from qiskit.visualization import plot_histogram, plot_distribution, plot_gate_map
###from qiskit_braket_provider import AWSBraketBackend
from qiskit import qasm3
from qiskit_aer.primitives import Estimator

# %%
mlAnglesIBMService = QiskitRuntimeService(channel="ibm_quantum", token="71b8d06738c8bf98495b52ba6888c6c654ffa481c806fc52104d8e80a6743bbd1363c74398fd924401ebb588c52a01b0fd8a292df0df11104c97d07b5d4236be")

# %%
mlAnglesIBMService.instances()
# Out:
# ['ibm-q/open/main']

# %%
# IN THE CURRENT QUANTUM KIT ONLY FOR REGIONS ARE AVAILABLE
# [<IBMBackend('ibm_brisbane')>,
#  <IBMBackend('ibm_kyoto')>,
#  <IBMBackend('ibm_osaka')>,
#  <IBMBackend('ibm_sherbrooke')>]
mlangelsBackend =   mlAnglesIBMService.backend(name='ibm_sherbrooke')
mlangelsBackend
# Out:
# <IBMBackend('ibm_sherbrooke')>

# %%
mlangelsBackend.status()
# Out:
# <pre>&lt;qiskit.providers.models.backendstatus.BackendStatus object at 0x7ef18c71b610&gt;</pre><b>name</b>: ibm_sherbrooke<br/><b>version</b>: , <b>pending jobs</b>: 3425<br/><b>status</b>: active<br/>

# %%
mlangelsBackend.num_qubits
# Out:
# 127

# %%
mlangelsBackend.coupling_map

# %%
mlangelsBackend.dt
# Out:
# 2.2222222222222221e-10

# %%
mlangelsBackend.options
# Out:
# Options(shots=4000, memory=False, meas_level=<MeasLevel.CLASSIFIED: 2>, meas_return=<MeasReturnType.AVERAGE: 'avg'>, memory_slots=None, memory_slot_size=100, rep_time=None, rep_delay=None, init_qubits=True, use_measure_esp=None, use_fractional_gates=False, noise_model=None, seed_simulator=None)

# %%
mlangelsAllQPU =   mlAnglesIBMService.backends()
mlangelsAllQPU
# Out:
# [<IBMBackend('ibm_brisbane')>,
#  <IBMBackend('ibm_kyoto')>,
#  <IBMBackend('ibm_osaka')>,
#  <IBMBackend('ibm_sherbrooke')>]

# %%
activeAccountDetails = mlAnglesIBMService.active_account()
activeAccountDetails
# Out:
# {'channel': 'ibm_quantum',
#  'url': 'https://auth.quantum-computing.ibm.com/api',
#  'token': '71b8d06738c8bf98495b52ba6888c6c654ffa481c806fc52104d8e80a6743bbd1363c74398fd924401ebb588c52a01b0fd8a292df0df11104c97d07b5d4236be',
#  'verify': True,
#  'private_endpoint': False}

# %%
mlAngleIBMInstanceName = mlAnglesIBMService.instances()
mlAngleIBMInstanceName
# Out:
# ['ibm-q/open/main']

# %%
mlAnglesIBMService.jobs()[0].inputs
#creation_date
# Out:
# {'qobj_id': '854611aa-05bb-462b-a062-9193ec9b528c',
#  'header': {'backend_name': 'ibmq_quito', 'backend_version': '1.1.35'},
#  'config': {'shots': 4000,
#   'memory': False,
#   'parameter_binds': [],
#   'meas_level': 2,
#   'n_qubits': 5,
#   'rep_delay': 250,
#   'init_qubits': True,
#   'use_measure_esp': False,
#   'parametric_pulses': ['gaussian', 'gaussian_square', 'drag', 'constant'],
#   'memory_slots': 5},
#  'schema_version': '1.3.0',
#  'type': 'QASM',
#  'experiments': [{'config': {'n_qubits': 5, 'memory_slots': 5},
#    'header': {'qubit_labels': [['q', 0],
#      ['q', 1],
#      ['q', 2],
#      ['q', 3],
#      ['q', 4]],
#     'n_qubits': 5,
#     'qreg_sizes': [['q', 5]],
#     'clbit_labels': [['meas', 0],
#      ['meas', 1],
#      ['meas', 2],
#      ['meas', 3],
#      ['meas', 4]],
#     'memory_slots': 5,
#     'creg_sizes': [['meas', 5]],
#     'name': 'quantum_volume_[5,5,417]',
#     'global_phase': 5.478750727060646,
#     'metadata': {}},
#    'instructions': [{'name': 'rz',
#      'params': [-2.7628514564312],
#      'qubits': [0]},
#     {'name': 'sx', 'qubits': [0]},
#     {'name': 'rz', 'params': [-2.6312216878335066], 'qubits': [0]},
#     {'name': 'sx', 'qubits': [0]},
#     {'name': 'rz', 'params': [-1.8775653026752916], 'qubits': [0]},
#     {'name': 'rz', 'params': [0.10158423105621317], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [1]},
#     {'name': 'rz', 'params': [-1.7486253237309821], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [1]},
#     {'name': 'rz', 'params': [1.995326122331818], 'qubits': [1]},
#     {'name': 'rz', 'params': [1.406779867546562], 'qubits': [2]},
#     {'name': 'sx', 'qubits': [2]},
#     {'name': 'rz', 'params': [-1.6992155118673207], 'qubits': [2]},
#     {'name': 'sx', 'qubits': [2]},
#     {'name': 'rz', 'params': [1.793243408288018], 'qubits': [2]},
#     {'name': 'cx', 'qubits': [2, 1]},
#     {'name': 'rz', 'params': [0.9259743082498647], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [2]},
#     {'name': 'rz', 'params': [-3.0468002184916774], 'qubits': [2]},
#     {'name': 'cx', 'qubits': [2, 1]},
#     {'name': 'rz', 'params': [0.2729621637712414], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [2]},
#     {'name': 'cx', 'qubits': [2, 1]},
#     {'name': 'rz', 'params': [1.7155454491550568], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [1]},
#     {'name': 'rz', 'params': [-1.4006980451711897], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [1]},
#     {'name': 'rz', 'params': [1.7072766003717303], 'qubits': [1]},
#     {'name': 'cx', 'qubits': [0, 1]},
#     {'name': 'sx', 'qubits': [0]},
#     {'name': 'rz', 'params': [-3.048672199631121], 'qubits': [0]},
#     {'name': 'rz', 'params': [-0.9844424870255774], 'qubits': [1]},
#     {'name': 'cx', 'qubits': [0, 1]},
#     {'name': 'sx', 'qubits': [0]},
#     {'name': 'rz', 'params': [0.22436502956409268], 'qubits': [1]},
#     {'name': 'cx', 'qubits': [0, 1]},
#     {'name': 'rz', 'params': [-1.4201783030385526], 'qubits': [0]},
#     {'name': 'sx', 'qubits': [0]},
#     {'name': 'rz', 'params': [-1.3697942051790157], 'qubits': [0]},
#     {'name': 'sx', 'qubits': [0]},
#     {'name': 'rz', 'params': [-1.3631922671735346], 'qubits': [0]},
#     {'name': 'rz', 'params': [1.8138339527905787], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [1]},
#     {'name': 'rz', 'params': [-2.5393741667418483], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [1]},
#     {'name': 'rz', 'params': [1.7868123640676519], 'qubits': [1]},
#     {'name': 'rz', 'params': [1.7390092231194458], 'qubits': [2]},
#     {'name': 'sx', 'qubits': [2]},
#     {'name': 'rz', 'params': [-2.1193854190942254], 'qubits': [2]},
#     {'name': 'sx', 'qubits': [2]},
#     {'name': 'rz', 'params': [-2.7224173331997967], 'qubits': [2]},
#     {'name': 'cx', 'qubits': [1, 2]},
#     {'name': 'cx', 'qubits': [2, 1]},
#     {'name': 'cx', 'qubits': [1, 2]},
#     {'name': 'rz', 'params': [-0.7070842344701394], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [1]},
#     {'name': 'rz', 'params': [-1.4888983127166542], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [1]},
#     {'name': 'rz', 'params': [0.05327411998849518], 'qubits': [1]},
#     {'name': 'rz', 'params': [0.06376804256152768], 'qubits': [2]},
#     {'name': 'sx', 'qubits': [2]},
#     {'name': 'rz', 'params': [-1.3560354091281486], 'qubits': [2]},
#     {'name': 'sx', 'qubits': [2]},
#     {'name': 'rz', 'params': [-2.744631131694221], 'qubits': [2]},
#     {'name': 'rz', 'params': [0.41599317487834453], 'qubits': [3]},
#     {'name': 'sx', 'qubits': [3]},
#     {'name': 'rz', 'params': [-1.1296984190115928], 'qubits': [3]},
#     {'name': 'sx', 'qubits': [3]},
#     {'name': 'rz', 'params': [-0.3567342955160835], 'qubits': [3]},
#     {'name': 'rz', 'params': [0.1992243769809119], 'qubits': [4]},
#     {'name': 'sx', 'qubits': [4]},
#     {'name': 'rz', 'params': [-0.4608471026730516], 'qubits': [4]},
#     {'name': 'sx', 'qubits': [4]},
#     {'name': 'rz', 'params': [-1.5179062337330391], 'qubits': [4]},
#     {'name': 'cx', 'qubits': [3, 4]},
#     {'name': 'sx', 'qubits': [3]},
#     {'name': 'rz', 'params': [-2.833134847820456], 'qubits': [3]},
#     {'name': 'rz', 'params': [0.60208358885857], 'qubits': [4]},
#     {'name': 'cx', 'qubits': [3, 4]},
#     {'name': 'sx', 'qubits': [3]},
#     {'name': 'rz', 'params': [0.09388566426873425], 'qubits': [4]},
#     {'name': 'cx', 'qubits': [3, 4]},
#     {'name': 'rz', 'params': [-1.0952188938315883], 'qubits': [3]},
#     {'name': 'sx', 'qubits': [3]},
#     {'name': 'rz', 'params': [-1.3176238337552277], 'qubits': [3]},
#     {'name': 'sx', 'qubits': [3]},
#     {'name': 'rz', 'params': [1.8250806237588613], 'qubits': [3]},
#     {'name': 'cx', 'qubits': [1, 3]},
#     {'name': 'sx', 'qubits': [1]},
#     {'name': 'rz', 'params': [-2.746232691287406], 'qubits': [1]},
#     {'name': 'rz', 'params': [-0.8106145354700467], 'qubits': [3]},
#     {'name': 'cx', 'qubits': [1, 3]},
#     {'name': 'sx', 'qubits': [1]},
#     {'name': 'rz', 'params': [0.04705971724346029], 'qubits': [3]},
#     {'name': 'cx', 'qubits': [1, 3]},
#     {'name': 'rz', 'params': [2.925223842358747], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [1]},
#     {'name': 'rz', 'params': [-1.2340027439804935], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [1]},
#     {'name': 'rz', 'params': [3.118641889490256], 'qubits': [1]},
#     {'name': 'rz', 'params': [-3.0900970972525865], 'qubits': [3]},
#     {'name': 'sx', 'qubits': [3]},
#     {'name': 'rz', 'params': [-2.4100703081474384], 'qubits': [3]},
#     {'name': 'sx', 'qubits': [3]},
#     {'name': 'rz', 'params': [-0.24933360971845175], 'qubits': [3]},
#     {'name': 'cx', 'qubits': [1, 3]},
#     {'name': 'cx', 'qubits': [3, 1]},
#     {'name': 'cx', 'qubits': [1, 3]},
#     {'name': 'rz', 'params': [1.9010180555043954], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [1]},
#     {'name': 'rz', 'params': [-1.9143889971100032], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [1]},
#     {'name': 'rz', 'params': [1.808918513880748], 'qubits': [1]},
#     {'name': 'cx', 'qubits': [2, 1]},
#     {'name': 'rz', 'params': [0.7439080906963415], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [2]},
#     {'name': 'rz', 'params': [-2.924887747252905], 'qubits': [2]},
#     {'name': 'cx', 'qubits': [2, 1]},
#     {'name': 'rz', 'params': [0.41645641531328603], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [2]},
#     {'name': 'cx', 'qubits': [2, 1]},
#     {'name': 'rz', 'params': [-2.420361833603687], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [1]},
#     {'name': 'rz', 'params': [-1.2509373284549312], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [1]},
#     {'name': 'rz', 'params': [-1.228126778909667], 'qubits': [1]},
#     {'name': 'cx', 'qubits': [0, 1]},
#     {'name': 'sx', 'qubits': [0]},
#     {'name': 'rz', 'params': [-2.899419825121462], 'qubits': [0]},
#     {'name': 'rz', 'params': [-0.9401260389476495], 'qubits': [1]},
#     {'name': 'cx', 'qubits': [0, 1]},
#     {'name': 'sx', 'qubits': [0]},
#     {'name': 'rz', 'params': [0.6157208587500574], 'qubits': [1]},
#     {'name': 'cx', 'qubits': [0, 1]},
#     {'name': 'rz', 'params': [-2.162826941753759], 'qubits': [0]},
#     {'name': 'sx', 'qubits': [0]},
#     {'name': 'rz', 'params': [-1.1083532796631186], 'qubits': [0]},
#     {'name': 'sx', 'qubits': [0]},
#     {'name': 'rz', 'params': [-0.15155830176112017], 'qubits': [0]},
#     {'name': 'rz', 'params': [-0.06235731047256099], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [1]},
#     {'name': 'rz', 'params': [-2.496664522124288], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [1]},
#     {'name': 'rz', 'params': [0.8758707030337067], 'qubits': [1]},
#     {'name': 'rz', 'params': [-0.428337604012643], 'qubits': [2]},
#     {'name': 'sx', 'qubits': [2]},
#     {'name': 'rz', 'params': [-2.2086822908996995], 'qubits': [2]},
#     {'name': 'sx', 'qubits': [2]},
#     {'name': 'rz', 'params': [-1.7315797959519585], 'qubits': [2]},
#     {'name': 'cx', 'qubits': [2, 1]},
#     {'name': 'cx', 'qubits': [1, 2]},
#     {'name': 'cx', 'qubits': [2, 1]},
#     {'name': 'rz', 'params': [-0.05835093654372914], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [1]},
#     {'name': 'rz', 'params': [-1.045027964437585], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [1]},
#     {'name': 'rz', 'params': [-2.4967020665682345], 'qubits': [1]},
#     {'name': 'rz', 'params': [2.9512292946494423], 'qubits': [2]},
#     {'name': 'sx', 'qubits': [2]},
#     {'name': 'rz', 'params': [-1.444361477462829], 'qubits': [2]},
#     {'name': 'sx', 'qubits': [2]},
#     {'name': 'rz', 'params': [0.3756884379708305], 'qubits': [2]},
#     {'name': 'rz', 'params': [-0.7045891732181766], 'qubits': [3]},
#     {'name': 'sx', 'qubits': [3]},
#     {'name': 'rz', 'params': [-1.960786629764689], 'qubits': [3]},
#     {'name': 'sx', 'qubits': [3]},
#     {'name': 'rz', 'params': [-0.06606812226841008], 'qubits': [3]},
#     {'name': 'rz', 'params': [-2.8898713550954396], 'qubits': [4]},
#     {'name': 'sx', 'qubits': [4]},
#     {'name': 'rz', 'params': [-0.6028732109760995], 'qubits': [4]},
#     {'name': 'sx', 'qubits': [4]},
#     {'name': 'rz', 'params': [2.959703820234748], 'qubits': [4]},
#     {'name': 'cx', 'qubits': [3, 4]},
#     {'name': 'sx', 'qubits': [3]},
#     {'name': 'rz', 'params': [-2.3755573724763988], 'qubits': [3]},
#     {'name': 'rz', 'params': [0.5072040177117783], 'qubits': [4]},
#     {'name': 'cx', 'qubits': [3, 4]},
#     {'name': 'sx', 'qubits': [3]},
#     {'name': 'rz', 'params': [0.22748469611877012], 'qubits': [4]},
#     {'name': 'cx', 'qubits': [3, 4]},
#     {'name': 'rz', 'params': [1.807994484676823], 'qubits': [3]},
#     {'name': 'sx', 'qubits': [3]},
#     {'name': 'rz', 'params': [-1.5306168233046495], 'qubits': [3]},
#     {'name': 'sx', 'qubits': [3]},
#     {'name': 'rz', 'params': [-0.358019913438433], 'qubits': [3]},
#     {'name': 'cx', 'qubits': [1, 3]},
#     {'name': 'sx', 'qubits': [1]},
#     {'name': 'rz', 'params': [-3.0971734270675304], 'qubits': [1]},
#     {'name': 'rz', 'params': [0.660106170548629], 'qubits': [3]},
#     {'name': 'cx', 'qubits': [1, 3]},
#     {'name': 'sx', 'qubits': [1]},
#     {'name': 'rz', 'params': [0.03959427472612537], 'qubits': [3]},
#     {'name': 'cx', 'qubits': [1, 3]},
#     {'name': 'rz', 'params': [-2.965144021472792], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [1]},
#     {'name': 'rz', 'params': [-2.5517538076280797], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [1]},
#     {'name': 'rz', 'params': [-0.29229465249893494], 'qubits': [1]},
#     {'name': 'cx', 'qubits': [2, 1]},
#     {'name': 'rz', 'params': [-0.5615139540092391], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [2]},
#     {'name': 'rz', 'params': [-2.874013099859651], 'qubits': [2]},
#     {'name': 'cx', 'qubits': [2, 1]},
#     {'name': 'rz', 'params': [0.34152000313784847], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [2]},
#     {'name': 'cx', 'qubits': [2, 1]},
#     {'name': 'rz', 'params': [0.7490665985219778], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [1]},
#     {'name': 'rz', 'params': [-0.5277095100393243], 'qubits': [1]},
#     {'name': 'sx', 'qubits': [1]},
#     {'name': 'rz', 'params': [-0.3667512941313831], 'qubits': [1]},
#     {'name': 'rz', 'params': [0.49156731686724875], 'qubits': [2]},
#     {'name': 'sx', 'qubits': [2]},
#     {'name': 'rz', 'params': [-0.9657067059934388], 'qubits': [2]},
#     {'name': 'sx', 'qubits': [2]},
#     {'name': 'rz', 'params': [-2.0261914763929845], 'qubits': [2]},
#     {'name': 'rz', 'params': [3.0848103305560093], 'qubits': [3]},
#     {'name': 'sx', 'qubits': [3]},
#     {'name': 'rz', 'params': [-0.5825229523682935], 'qubits': [3]},
#     {'name': 'sx', 'qubits': [3]},
#     {'name': 'rz', 'params': [0.15429647073623798], 'qubits': [3]},
#     {'name': 'rz', 'params': [2.289506700757366], 'qubits': [4]},
#     {'name': 'sx', 'qubits': [4]},
#     {'name': 'rz', 'params': [-1.4134747314760574], 'qubits': [4]},
#     {'name': 'sx', 'qubits': [4]},
#     {'name': 'rz', 'params': [0.22684798756953484], 'qubits': [4]},
#     {'name': 'cx', 'qubits': [3, 4]},
#     {'name': 'sx', 'qubits': [3]},
#     {'name': 'rz', 'params': [-2.7453116358238328], 'qubits': [3]},
#     {'name': 'rz', 'params': [0.4711569004842589], 'qubits': [4]},
#     {'name': 'cx', 'qubits': [3, 4]},
#     {'name': 'sx', 'qubits': [3]},
#     {'name': 'rz', 'params': [0.0642517693786162], 'qubits': [4]},
#     {'name': 'cx', 'qubits': [3, 4]},
#     {'name': 'rz', 'params': [2.54543391048926], 'qubits': [3]},
#     {'name': 'sx', 'qubits': [3]},
#     {'name': 'rz', 'params': [-1.808732563712864], 'qubits': [3]},
#     {'name': 'sx', 'qubits': [3]},
#     {'name': 'rz', 'params': [-1.7600588991021517], 'qubits': [3]},
#     {'name': 'rz', 'params': [-2.2737007693040554], 'qubits': [4]},
#     {'name': 'sx', 'qubits': [4]},
#     {'name': 'rz', 'params': [-0.9963622927051308], 'qubits': [4]},
#     {'name': 'sx', 'qubits': [4]},
#     {'name': 'rz', 'params': [-0.8023463928361774], 'qubits': [4]},
#     {'name': 'barrier', 'qubits': [1, 4, 2, 0, 3]},
#     {'name': 'measure', 'qubits': [2], 'memory': [0]},
#     {'name': 'measure', 'qubits': [0], 'memory': [1]},
#     {'name': 'measure', 'qubits': [1], 'memory': [2]},
#     {'name': 'measure', 'qubits': [3], 'memory': [3]},
#     {'name': 'measure', 'qubits': [4], 'memory': [4]}]}]}

# %%
mlAnglesIBMService.jobs()[0].metrics()
# Out:
# {'timestamps': {'created': '2022-11-23T19:44:50.626Z',
#   'finished': '2022-11-23T19:49:21.495Z',
#   'running': '2022-11-23T19:49:14.932Z'},
#  'bss': {'seconds': 4},
#  'usage': {'quantum_seconds': 4, 'seconds': 4},
#  'num_qubits': [5],
#  'qiskit_version': 'qiskit/0.39.2/lab.quantum-computing.ibm.com',
#  'estimated_start_time': '0001-01-01T00:00:00Z',
#  'estimated_completion_time': '0001-01-01T00:00:00Z'}

# %%
mlAnglesIBMService.jobs()[0]
# Out:
# <RuntimeJob('637e7832e0f73051e59c20ef', 'circuit_runner')>

# %%
mlAnglesIBMService.jobs()[0].job_id()
# Out:
# '637e7832e0f73051e59c20ef'

# %%
mlAnglesIBMService.jobs()[0].primitive_id
# Out:
# 'circuit_runner'
